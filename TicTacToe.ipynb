# %%
from abc import ABC, abstractmethod
import os
import pickle
import collections
import numpy as np
import random


class Learner(ABC):
    """
    Parent class for Q-learning and SARSA agents.

    Parameters
    ----------
    alpha : float
        learning rate
    gamma : float
        temporal discounting rate
    eps : float
        probability of random action vs. greedy action
    eps_decay : float
        epsilon decay rate. Larger value = more decay
    """
    def __init__(self, alpha, gamma, eps, eps_decay=0., size=3):
        # Agent parameters
        self.size = size
        self.alpha = alpha
        self.gamma = gamma
        self.eps = eps
        self.eps_decay = eps_decay
        # Possible actions correspond to the set of all x,y coordinate pairs
        self.actions = []
        for i in range(size):
            for j in range(size):
                self.actions.append((i,j))
        # Initialize Q values to 0 for all state-action pairs.
        # Access value for action a, state s via Q[a][s]
        self.Q = {}
        for action in self.actions:
            self.Q[action] = collections.defaultdict(int)
        # Keep a list of reward received at each episode
        self.rewards = []

    def get_action(self, s):
        """
        Select an action given the current game state.

        Parameters
        ----------
        s : string
            state
        """
        # Only consider the allowed actions (empty board spaces)
        possible_actions = [a for a in self.actions if s[a[0]*self.size + a[1]] == '-']
        if random.random() < self.eps:
            # Random choose.
            action = possible_actions[random.randint(0,len(possible_actions)-1)]
        else:
            # Greedy choose.
            values = np.array([self.Q[a][s] for a in possible_actions])
            # Find location of max
            ix_max = np.where(values == np.max(values))[0]
            if len(ix_max) > 1:
                # If multiple actions were max, then sample from them
                ix_select = np.random.choice(ix_max, 1)[0]
            else:
                # If unique max action, select that one
                ix_select = ix_max[0]
            action = possible_actions[ix_select]

        # update epsilon; geometric decay
        self.eps *= (1.-self.eps_decay)

        return action

    def save(self, path):
        """ Pickle the agent object instance to save the agent's state. """
        if os.path.isfile(path):
            os.remove(path)
        f = open(path, 'wb')
        pickle.dump(self, f)
        f.close()

    @abstractmethod
    def update(self, s, s_, a, a_, r):
        pass

    @abstractmethod
    def update_by_episode(self, episode):
        pass


class MonteCarlo(Learner):

    def __init__(self, alpha, gamma, eps, eps_decay=0., size=3):
        super().__init__(alpha, gamma, eps, eps_decay, size)
        self.N = collections.defaultdict(int)

    def update(self, s, s_, a, a_, r):
        self.N[s] += 1
        self.Q[a][s] += 1 / self.N[s] * (r + self.gamma * self.Q[a_][s_] - self.Q[a][s])

    def update_by_episode(self, episode):
        episode = episode[::-1]

        for i in range(len(episode) - 1):
            s, a, s_, r = episode[i]
            a_ = episode[i + 1][1]
            self.update(s, s_, a, a_, r)
        self.rewards.append(episode[0][3])

class Qlearner(Learner):
    """
    A class to implement the Q-learning agent.
    """
    def __init__(self, alpha, gamma, eps, eps_decay=0.,size=None):
        super().__init__(alpha, gamma, eps, eps_decay,size)

    def update(self, s, s_, a, a_, r):
        """
        Perform the Q-Learning update of Q values.

        Parameters
        ----------
        s : string
            previous state
        s_ : string
            new state
        a : (i,j) tuple
            previous action
        a_ : (i,j) tuple
            new action. NOT used by Q-learner!
        r : int
            reward received after executing action "a" in state "s"
        """
        # Update Q(s,a)
        if s_ is not None:
            # hold list of Q values for all a_,s_ pairs. We will access the max later
            possible_actions = [action for action in self.actions if s_[action[0]*self.size + action[1]] == '-']
            Q_options = [self.Q[action][s_] for action in possible_actions]
            # update
            self.Q[a][s] += self.alpha*(r + self.gamma*max(Q_options) - self.Q[a][s])
        else:
            # terminal state update
            self.Q[a][s] += self.alpha*(r - self.Q[a][s])

        # add r to rewards list
        self.rewards.append(r)
    def update_by_episode(self, episode):
        """
        Updates the Q-values based on an entire episode of experience.

        Parameters
        ----------
        episode : list of tuples
            A list of (state, action, next_state, reward) tuples representing the episode.
        """
        # Iterate through the episode and update Q-values
        for i in range(len(episode) - 1):
            s, a, s_, r = episode[i]

            # Get the next action from the episode
            a_ = episode[i + 1][1]

            # Perform the Q-learning update
            self.update(s, s_, a, a_, r)

        # Append the reward from the last step of the episode
        self.rewards.append(episode[-1][3]) # Append the reward for the final state

class SARSAlearner(Learner):
    """
    A class to implement the SARSA agent.
    """
    def __init__(self, alpha, gamma, eps, eps_decay=0.,size=None):
        super().__init__(alpha, gamma, eps, eps_decay, size)

    def update(self, s, s_, a, a_, r):
        """
        Perform the SARSA update of Q values.

        Parameters
        ----------
        s : string
            previous state
        s_ : string
            new state
        a : (i,j) tuple
            previous action
        a_ : (i,j) tuple
            new action
        r : int
            reward received after executing action "a" in state "s"
        """
        # Update Q(s,a)
        if s_ is not None:
            self.Q[a][s] += self.alpha*(r + self.gamma*self.Q[a_][s_] - self.Q[a][s])
        else:
            # terminal state update
            self.Q[a][s] += self.alpha*(r - self.Q[a][s])

        # add r to rewards list
        self.rewards.append(r)

    def update_by_episode(self, episode):
        """
        Updates the Q-values based on an entire episode of experience.

        Parameters
        ----------
        episode : list of tuples
            A list of (state, action, next_state, reward) tuples representing the episode.
        """
        # Implement SARSA update logic here for the entire episode
        # This is just a placeholder, you need to implement the actual logic
        for i in range(len(episode) - 1):
            s, a, s_, r = episode[i]

            # Get the next action (a_) from the next step in the episode
            a_ = episode[i + 1][1]

            # Now perform the SARSA update
            self.update(s, s_, a, a_, r)

        # Append the reward from the last step of the episode
        self.rewards.append(episode[-1][-1])

# %%
import random

class Game:

    def __init__(self, agent_1, agent_2, size=3):
        self.agent_1 = agent_1
        self.agent_2 = agent_2
        self.size = size
        self.board = [['-' for _ in range(size)] for _ in range(size)]


    def agent1Move(self, action):
        self.board[action[0]][action[1]] = 'O'

    def agent2Move(self, action):
        self.board[action[0]][action[1]] = 'X'

    def checkForWin(self, key):

        diag1 = [self.board[i][i] for i in range(self.size)]
        diag2 = [self.board[i][self.size - i - 1] for i in range(self.size)]
        if diag1.count(key) == self.size or diag2.count(key) == self.size:
            return True

        for i in range(self.size):
            row = [self.board[i][j] for j in range(self.size)]
            col = [self.board[j][i] for j in range(self.size)]
            if row.count(key) == self.size or col.count(key) == self.size:
                return True

        return False

    def checkForDraw(self):
        return all(elt != '-' for row in self.board for elt in row)

    def checkForEnd(self, key):
        if self.checkForWin(key):
            return 1
        elif self.checkForDraw():
            return 0
        return -1

    def playGame(self):
        agent1_episode = []
        agent2_episode = []
        agent1_prev_state = getStateKey(self.board)
        agent1_action = self.agent_1.get_action(agent1_prev_state)
        self.agent1Move(agent1_action)
        while True:
            agent2_prev_state = getStateKey(self.board)
            agent2_action = self.agent_2.get_action(agent2_prev_state)
            self.agent2Move(agent2_action)
            if self.checkForEnd('X') != -1:
                reward = self.checkForEnd('X')
                agent1_episode.append((agent1_prev_state, agent1_action, agent2_prev_state, -reward))
                agent2_episode.append((agent2_prev_state, agent2_action, getStateKey(self.board), reward))
                break
            else:
                reward = 0
                agent1_episode.append((agent1_prev_state, agent1_action, agent2_prev_state, reward))
            agent1_prev_state = getStateKey(self.board)
            agent1_action = self.agent_1.get_action(agent1_prev_state)
            self.agent1Move(agent1_action)
            if self.checkForEnd('O') != -1:
                reward = self.checkForEnd('O')
                agent1_episode.append((agent1_prev_state, agent1_action, getStateKey(self.board), reward))
                agent2_episode.append((agent2_prev_state, agent2_action, agent1_prev_state, -reward))
                break
            else:
                reward = 0
                agent2_episode.append((agent2_prev_state, agent2_action, agent1_prev_state, reward))

        self.agent_1.update_by_episode(agent1_episode)
        self.agent_2.update_by_episode(agent2_episode)
        print(agent1_episode)
        print(agent2_episode)
        print("-"*100)


    def start(self, episodes=1000):
        for _ in range(episodes):
            print(f"{_}:")
            self.playGame()
            self.board = [['-' for _ in range(self.size)] for _ in range(self.size)]
        self.agent_1.save('agent_1.pkl')
        self.agent_2.save('agent_2.pkl')



def printBoard(board, size):
    """
    Prints the game board as text output to the terminal.

    Parameters
    ----------
    board : list of lists
        the current game board
    size : int
        the size of the board (3, 4, or 5)
    """
    header = '    ' + '   '.join(str(i) for i in range(size))
    print(header + '\n')
    for i, row in enumerate(board):
        print('%i   ' % i, end='')
        for elt in row:
            print('%s   ' % elt, end='')
        print('\n')


def getStateKey(board):
    """
    Converts 2D list representing the board state into a string key
    for that state. Keys are used for Q-value hashing.

    Parameters
    ----------
    board : list of lists
        the current game board
    """
    return ''.join(''.join(row) for row in board)

# %%
agent1 = SARSAlearner(alpha=0.5, gamma=0.9, eps=0.1, size=4)
agent2 = Qlearner(alpha=0.5, gamma=0.9, eps=0.1, size=4)
game = Game(agent_1=agent1, agent_2=agent2, size=4)

print(game.start(10000))
# Out:
# Streaming output truncated to the last 5000 lines.
# [('----------------', (3, 3), '---------------O', 0), ('-------X-------O', (0, 0), 'O------X-------O', 0), ('O--X---X-------O', (1, 1), 'O--X-O-X-------O', 0), ('O--X-O-X-X-----O', (1, 0), 'O--XOO-X-X-----O', 0), ('O--XOO-X-X--X--O', (2, 0), 'O--XOO-XOX--X--O', 0), ('O--XOO-XOXX-X--O', (2, 3), 'O--XOO-XOXXOX--O', 0), ('O--XOO-XOXXOX-XO', (3, 1), 'O--XOO-XOXXOXOXO', 0), ('O-XXOO-XOXXOXOXO', (1, 2), 'O-XXOOOXOXXOXOXO', 0)]
# [('---------------O', (1, 3), '-------X-------O', 0), ('O------X-------O', (0, 3), 'O--X---X-------O', 0), ('O--X-O-X-------O', (2, 1), 'O--X-O-X-X-----O', 0), ('O--XOO-X-X-----O', (3, 0), 'O--XOO-X-X--X--O', 0), ('O--XOO-XOX--X--O', (2, 2), 'O--XOO-XOXX-X--O', 0), ('O--XOO-XOXXOX--O', (3, 2), 'O--XOO-XOXXOX-XO', 0), ('O--XOO-XOXXOXOXO', (0, 2), 'O-XXOO-XOXXOXOXO', 0), ('O-XXOOOXOXXOXOXO', (0, 1), 'OXXXOOOXOXXOXOXO', 0)]
# ----------------------------------------------------------------------------------------------------
# 8751:
# [('----------------', (0, 0), 'O---------------', 0), ('OX--------------', (2, 0), 'OX------O-------', 0), ('OX------O----X--', (3, 2), 'OX------O----XO-', 0), ('OX---X--O----XO-', (2, 1), 'OX---X--OO---XO-', 0), ('OX---X-XOO---XO-', (1, 2), 'OX---XOXOO---XO-', 0), ('OX---XOXOO--XXO-', (3, 3), 'OX---XOXOO--XXOO', 0), ('OX---XOXOOX-XXOO', (2, 3), 'OX---XOXOOXOXXOO', 0), ('OX-X-XOXOOXOXXOO', (0, 2), 'OXOX-XOXOOXOXXOO', 0)]
# [('O---------------', (0, 1), 'OX--------------', 0), ('OX------O-------', (3, 1), 'OX------O----X--', 0), ('OX------O----XO-', (1, 1), 'OX---X--O----XO-', 0), ('OX---X--OO---XO-', (1, 3), 'OX---X-XOO---XO-', 0), ('OX---XOXOO---XO-', (3, 0), 'OX---XOXOO--XXO-', 0), ('OX---XOXOO--XXOO', (2, 2), 'OX---XOXOOX-XXOO', 0), ('OX---XOXOOXOXXOO', (0, 3), 'OX-X-XOXOOXOXXOO', 0), ('OXOX-XOXOOXOXXOO', (1, 0), 'OXOXXXOXOOXOXXOO', 0)]
# ----------------------------------------------------------------------------------------------------
# 8752:
# [('----------------', (3, 3), '---------------O', 0), ('-------X-------O', (1, 0), '----O--X-------O', 0), ('-X--O--X-------O', (0, 3), '-X-OO--X-------O', 0), ('-X-OO--X-----X-O', (2, 1), '-X-OO--X-O---X-O', 0), ('-X-OO--XXO---X-O', (2, 2), '-X-OO--XXOO--X-O', 0), ('-X-OOX-XXOO--X-O', (3, 2), '-X-OOX-XXOO--XOO', 0), ('XX-OOX-XXOO--XOO', (2, 3), 'XX-OOX-XXOOO-XOO', 0), ('XX-OOX-XXOOOXXOO', (1, 2), 'XX-OOXOXXOOOXXOO', 0)]
# [('---------------O', (1, 3), '-------X-------O', 0), ('----O--X-------O', (0, 1), '-X--O--X-------O', 0), ('-X-OO--X-------O', (3, 1), '-X-OO--X-----X-O', 0), ('-X-OO--X-O---X-O', (2, 0), '-X-OO--XXO---X-O', 0), ('-X-OO--XXOO--X-O', (1, 1), '-X-OOX-XXOO--X-O', 0), ('-X-OOX-XXOO--XOO', (0, 0), 'XX-OOX-XXOO--XOO', 0), ('XX-OOX-XXOOO-XOO', (3, 0), 'XX-OOX-XXOOOXXOO', 0), ('XX-OOXOXXOOOXXOO', (0, 2), 'XXXOOXOXXOOOXXOO', 0)]
# ----------------------------------------------------------------------------------------------------
# 8753:
# [('----------------', (2, 2), '----------O-----', 0), ('-------X--O-----', (0, 2), '--O----X--O-----', 0), ('--O----XX-O-----', (3, 1), '--O----XX-O--O--', 0), ('X-O----XX-O--O--', (1, 1), 'X-O--O-XX-O--O--', 0), ('X-O--OXXX-O--O--', (3, 0), 'X-O--OXXX-O-OO--', 0), ('X-O--OXXX-O-OOX-', (3, 3), 'X-O--OXXX-O-OOXO', 0), ('XXO--OXXX-O-OOXO', (0, 3), 'XXOO-OXXX-O-OOXO', 0), ('XXOO-OXXXXO-OOXO', (2, 3), 'XXOO-OXXXXOOOOXO', 0)]
# [('----------O-----', (1, 3), '-------X--O-----', 0), ('--O----X--O-----', (2, 0), '--O----XX-O-----', 0), ('--O----XX-O--O--', (0, 0), 'X-O----XX-O--O--', 0), ('X-O--O-XX-O--O--', (1, 2), 'X-O--OXXX-O--O--', 0), ('X-O--OXXX-O-OO--', (3, 2), 'X-O--OXXX-O-OOX-', 0), ('X-O--OXXX-O-OOXO', (0, 1), 'XXO--OXXX-O-OOXO', 0), ('XXOO-OXXX-O-OOXO', (2, 1), 'XXOO-OXXXXO-OOXO', 0), ('XXOO-OXXXXOOOOXO', (1, 0), 'XXOOXOXXXXOOOOXO', 0)]
# ----------------------------------------------------------------------------------------------------
# 8754:
# [('----------------', (3, 1), '-------------O--', 0), ('----------X--O--', (1, 1), '-----O----X--O--', 0), ('-X---O----X--O--', (1, 3), '-X---O-O--X--O--', 0), ('-X---O-O--X-XO--', (3, 2), '-X---O-O--X-XOO-', 0), ('-X---O-O-XX-XOO-', (0, 0), 'OX---O-O-XX-XOO-', 0), ('OX---O-O-XXXXOO-', (0, 3), 'OX-O-O-O-XXXXOO-', 0), ('OX-OXO-O-XXXXOO-', (2, 0), 'OX-OXO-OOXXXXOO-', 0), ('OXXOXO-OOXXXXOO-', (3, 3), 'OXXOXO-OOXXXXOOO', 0)]
# [('-------------O--', (2, 2), '----------X--O--', 0), ('-----O----X--O--', (0, 1), '-X---O----X--O--', 0), ('-X---O-O--X--O--', (3, 0), '-X---O-O--X-XO--', 0), ('-X---O-O--X-XOO-', (2, 1), '-X---O-O-XX-XOO-', 0), ('OX---O-O-XX-XOO-', (2, 3), 'OX---O-O-XXXXOO-', 0), ('OX-O-O-O-XXXXOO-', (1, 0), 'OX-OXO-O-XXXXOO-', 0), ('OX-OXO-OOXXXXOO-', (0, 2), 'OXXOXO-OOXXXXOO-', 0), ('OXXOXO-OOXXXXOOO', (1, 2), 'OXXOXOXOOXXXXOOO', 0)]
# ----------------------------------------------------------------------------------------------------
# 8755:
# [('----------------', (2, 2), '----------O-----', 0), ('---------XO-----', (0, 2), '--O------XO-----', 0), ('--O------XO---X-', (2, 0), '--O-----OXO---X-', 0), ('--O-----OXO---XX', (3, 1), '--O-----OXO--OXX', 0), ('--O----XOXO--OXX', (3, 0), '--O----XOXO-OOXX', 0), ('--O---XXOXO-OOXX', (0, 3), '--OO--XXOXO-OOXX', 0), ('--OOX-XXOXO-OOXX', (0, 0), 'O-OOX-XXOXO-OOXX', -1)]
# [('----------O-----', (2, 1), '---------XO-----', 0), ('--O------XO-----', (3, 2), '--O------XO---X-', 0), ('--O-----OXO---X-', (3, 3), '--O-----OXO---XX', 0), ('--O-----OXO--OXX', (1, 3), '--O----XOXO--OXX', 0), ('--O----XOXO-OOXX', (1, 2), '--O---XXOXO-OOXX', 0), ('--OO--XXOXO-OOXX', (1, 0), '--OOX-XXOXO-OOXX', 0), ('O-OOX-XXOXO-OOXX', (1, 1), 'O-OOXXXXOXO-OOXX', 1)]
# ----------------------------------------------------------------------------------------------------
# 8756:
# [('----------------', (3, 3), '---------------O', 0), ('-X-------------O', (2, 1), '-X-------O-----O', 0), ('-X------XO-----O', (2, 2), '-X------XOO----O', 0), ('-X------XOO-X--O', (0, 3), '-X-O----XOO-X--O', 0), ('-X-O--X-XOO-X--O', (1, 3), '-X-O--XOXOO-X--O', 0), ('XX-O--XOXOO-X--O', (3, 1), 'XX-O--XOXOO-XO-O', 0), ('XX-O-XXOXOO-XO-O', (1, 0), 'XX-OOXXOXOO-XO-O', 0), ('XXXOOXXOXOO-XO-O', (2, 3), 'XXXOOXXOXOOOXO-O', 1)]
# [('---------------O', (0, 1), '-X-------------O', 0), ('-X-------O-----O', (2, 0), '-X------XO-----O', 0), ('-X------XOO----O', (3, 0), '-X------XOO-X--O', 0), ('-X-O----XOO-X--O', (1, 2), '-X-O--X-XOO-X--O', 0), ('-X-O--XOXOO-X--O', (0, 0), 'XX-O--XOXOO-X--O', 0), ('XX-O--XOXOO-XO-O', (1, 1), 'XX-O-XXOXOO-XO-O', 0), ('XX-OOXXOXOO-XO-O', (0, 2), 'XXXOOXXOXOO-XO-O', -1)]
# ----------------------------------------------------------------------------------------------------
# 8757:
# [('----------------', (3, 1), '-------------O--', 0), ('---------X---O--', (1, 2), '------O--X---O--', 0), ('------O--XX--O--', (0, 2), '--O---O--XX--O--', 0), ('--OX--O--XX--O--', (3, 3), '--OX--O--XX--O-O', 0), ('--OX--O--XX-XO-O', (1, 3), '--OX--OO-XX-XO-O', 0), ('--OX--OO-XXXXO-O', (1, 1), '--OX-OOO-XXXXO-O', -1)]
# [('-------------O--', (2, 1), '---------X---O--', 0), ('------O--X---O--', (2, 2), '------O--XX--O--', 0), ('--O---O--XX--O--', (0, 3), '--OX--O--XX--O--', 0), ('--OX--O--XX--O-O', (3, 0), '--OX--O--XX-XO-O', 0), ('--OX--OO-XX-XO-O', (2, 3), '--OX--OO-XXXXO-O', 0), ('--OX-OOO-XXXXO-O', (2, 0), '--OX-OOOXXXXXO-O', 1)]
# ----------------------------------------------------------------------------------------------------
# 8758:
# [('----------------', (1, 2), '------O---------', 0), ('-----XO---------', (2, 2), '-----XO---O-----', 0), ('-X---XO---O-----', (3, 3), '-X---XO---O----O', 0), ('-X---XO-X-O----O', (2, 3), '-X---XO-X-OO---O', 0), ('-X---XO-X-OO-X-O', (1, 3), '-X---XOOX-OO-X-O', 0), ('-X---XOOX-OO-XXO', (1, 0), '-X--OXOOX-OO-XXO', 0), ('-X-XOXOOX-OO-XXO', (0, 0), 'OX-XOXOOX-OO-XXO', -1)]
# [('------O---------', (1, 1), '-----XO---------', 0), ('-----XO---O-----', (0, 1), '-X---XO---O-----', 0), ('-X---XO---O----O', (2, 0), '-X---XO-X-O----O', 0), ('-X---XO-X-OO---O', (3, 1), '-X---XO-X-OO-X-O', 0), ('-X---XOOX-OO-X-O', (3, 2), '-X---XOOX-OO-XXO', 0), ('-X--OXOOX-OO-XXO', (0, 3), '-X-XOXOOX-OO-XXO', 0), ('OX-XOXOOX-OO-XXO', (2, 1), 'OX-XOXOOXXOO-XXO', 1)]
# ----------------------------------------------------------------------------------------------------
# 8759:
# [('----------------', (3, 0), '------------O---', 0), ('----------X-O---', (0, 1), '-O--------X-O---', 0), ('-O--X-----X-O---', (1, 1), '-O--XO----X-O---', 0), ('-O--XOX---X-O---', (0, 2), '-OO-XOX---X-O---', 0), ('-OO-XOX---X-OX--', (3, 2), '-OO-XOX---X-OXO-', 0), ('-OO-XOX---XXOXO-', (3, 3), '-OO-XOX---XXOXOO', 0), ('-OO-XOX--XXXOXOO', (0, 0), 'OOO-XOX--XXXOXOO', -1)]
# [('------------O---', (2, 2), '----------X-O---', 0), ('-O--------X-O---', (1, 0), '-O--X-----X-O---', 0), ('-O--XO----X-O---', (1, 2), '-O--XOX---X-O---', 0), ('-OO-XOX---X-O---', (3, 1), '-OO-XOX---X-OX--', 0), ('-OO-XOX---X-OXO-', (2, 3), '-OO-XOX---XXOXO-', 0), ('-OO-XOX---XXOXOO', (2, 1), '-OO-XOX--XXXOXOO', 0), ('OOO-XOX--XXXOXOO', (2, 0), 'OOO-XOX-XXXXOXOO', 1)]
# ----------------------------------------------------------------------------------------------------
# 8760:
# [('----------------', (2, 2), '----------O-----', 0), ('-X--------O-----', (1, 1), '-X---O----O-----', 0), ('-X-X-O----O-----', (0, 2), '-XOX-O----O-----', 0), ('-XOX-O-X--O-----', (1, 2), '-XOX-OOX--O-----', 0), ('-XOX-OOX--O-X---', (2, 1), '-XOX-OOX-OO-X---', 0), ('XXOX-OOX-OO-X---', (3, 3), 'XXOX-OOX-OO-X--O', 0), ('XXOXXOOX-OO-X--O', (2, 3), 'XXOXXOOX-OOOX--O', 0), ('XXOXXOOX-OOOXX-O', (3, 2), 'XXOXXOOX-OOOXXOO', 1)]
# [('----------O-----', (0, 1), '-X--------O-----', 0), ('-X---O----O-----', (0, 3), '-X-X-O----O-----', 0), ('-XOX-O----O-----', (1, 3), '-XOX-O-X--O-----', 0), ('-XOX-OOX--O-----', (3, 0), '-XOX-OOX--O-X---', 0), ('-XOX-OOX-OO-X---', (0, 0), 'XXOX-OOX-OO-X---', 0), ('XXOX-OOX-OO-X--O', (1, 0), 'XXOXXOOX-OO-X--O', 0), ('XXOXXOOX-OOOX--O', (3, 1), 'XXOXXOOX-OOOXX-O', -1)]
# ----------------------------------------------------------------------------------------------------
# 8761:
# [('----------------', (0, 3), '---O------------', 0), ('---O-------X----', (3, 0), '---O-------XO---', 0), ('---O-----X-XO---', (3, 3), '---O-----X-XO--O', 0), ('---O-X---X-XO--O', (2, 2), '---O-X---XOXO--O', 0), ('---O-X---XOXOX-O', (1, 3), '---O-X-O-XOXOX-O', 0), ('--XO-X-O-XOXOX-O', (1, 0), '--XOOX-O-XOXOX-O', 0), ('--XOOXXO-XOXOX-O', (0, 1), '-OXOOXXO-XOXOX-O', 0), ('-OXOOXXOXXOXOX-O', (3, 2), '-OXOOXXOXXOXOXOO', 0)]
# [('---O------------', (2, 3), '---O-------X----', 0), ('---O-------XO---', (2, 1), '---O-----X-XO---', 0), ('---O-----X-XO--O', (1, 1), '---O-X---X-XO--O', 0), ('---O-X---XOXO--O', (3, 1), '---O-X---XOXOX-O', 0), ('---O-X-O-XOXOX-O', (0, 2), '--XO-X-O-XOXOX-O', 0), ('--XOOX-O-XOXOX-O', (1, 2), '--XOOXXO-XOXOX-O', 0), ('-OXOOXXO-XOXOX-O', (2, 0), '-OXOOXXOXXOXOX-O', 0), ('-OXOOXXOXXOXOXOO', (0, 0), 'XOXOOXXOXXOXOXOO', 0)]
# ----------------------------------------------------------------------------------------------------
# 8762:
# [('----------------', (1, 3), '-------O--------', 0), ('------XO--------', (2, 2), '------XO--O-----', 0), ('------XO-XO-----', (3, 2), '------XO-XO---O-', 0), ('------XO-XOX--O-', (3, 0), '------XO-XOXO-O-', 0), ('------XO-XOXOXO-', (0, 3), '---O--XO-XOXOXO-', 0), ('---O--XO-XOXOXOX', (1, 1), '---O-OXO-XOXOXOX', 0), ('--XO-OXO-XOXOXOX', (0, 1), '-OXO-OXO-XOXOXOX', 0), ('XOXO-OXO-XOXOXOX', (2, 0), 'XOXO-OXOOXOXOXOX', 0)]
# [('-------O--------', (1, 2), '------XO--------', 0), ('------XO--O-----', (2, 1), '------XO-XO-----', 0), ('------XO-XO---O-', (2, 3), '------XO-XOX--O-', 0), ('------XO-XOXO-O-', (3, 1), '------XO-XOXOXO-', 0), ('---O--XO-XOXOXO-', (3, 3), '---O--XO-XOXOXOX', 0), ('---O-OXO-XOXOXOX', (0, 2), '--XO-OXO-XOXOXOX', 0), ('-OXO-OXO-XOXOXOX', (0, 0), 'XOXO-OXO-XOXOXOX', 0), ('XOXO-OXOOXOXOXOX', (1, 0), 'XOXOXOXOOXOXOXOX', 0)]
# ----------------------------------------------------------------------------------------------------
# 8763:
# [('----------------', (0, 2), '--O-------------', 0), ('--O------X------', (0, 0), 'O-O------X------', 0), ('O-O-X----X------', (0, 1), 'OOO-X----X------', 0), ('OOO-X----X----X-', (1, 3), 'OOO-X--O-X----X-', 0), ('OOO-X--O-X--X-X-', (3, 1), 'OOO-X--O-X--XOX-', 0), ('OOO-XX-O-X--XOX-', (0, 3), 'OOOOXX-O-X--XOX-', 1)]
# [('--O-------------', (2, 1), '--O------X------', 0), ('O-O------X------', (1, 0), 'O-O-X----X------', 0), ('OOO-X----X------', (3, 2), 'OOO-X----X----X-', 0), ('OOO-X--O-X----X-', (3, 0), 'OOO-X--O-X--X-X-', 0), ('OOO-X--O-X--XOX-', (1, 1), 'OOO-XX-O-X--XOX-', -1)]
# ----------------------------------------------------------------------------------------------------
# 8764:
# [('----------------', (3, 0), '------------O---', 0), ('------------O--X', (1, 3), '-------O----O--X', 0), ('-X-----O----O--X', (0, 3), '-X-O---O----O--X', 0), ('-XXO---O----O--X', (2, 0), '-XXO---OO---O--X', 0), ('-XXO---OO--XO--X', (1, 1), '-XXO-O-OO--XO--X', 0), ('-XXO-O-OO--XO-XX', (3, 1), '-XXO-O-OO--XOOXX', 0), ('XXXO-O-OO--XOOXX', (1, 2), 'XXXO-OOOO--XOOXX', 0), ('XXXOXOOOO--XOOXX', (2, 2), 'XXXOXOOOO-OXOOXX', 0)]
# [('------------O---', (3, 3), '------------O--X', 0), ('-------O----O--X', (0, 1), '-X-----O----O--X', 0), ('-X-O---O----O--X', (0, 2), '-XXO---O----O--X', 0), ('-XXO---OO---O--X', (2, 3), '-XXO---OO--XO--X', 0), ('-XXO-O-OO--XO--X', (3, 2), '-XXO-O-OO--XO-XX', 0), ('-XXO-O-OO--XOOXX', (0, 0), 'XXXO-O-OO--XOOXX', 0), ('XXXO-OOOO--XOOXX', (1, 0), 'XXXOXOOOO--XOOXX', 0), ('XXXOXOOOO-OXOOXX', (2, 1), 'XXXOXOOOOXOXOOXX', 0)]
# ----------------------------------------------------------------------------------------------------
# 8765:
# [('----------------', (3, 3), '---------------O', 0), ('-------X-------O', (3, 2), '-------X------OO', 0), ('-------X-X----OO', (1, 2), '------OX-X----OO', 0), ('X-----OX-X----OO', (1, 0), 'X---O-OX-X----OO', 0), ('X-X-O-OX-X----OO', (0, 3), 'X-XOO-OX-X----OO', 0), ('X-XOO-OX-X---XOO', (2, 3), 'X-XOO-OX-X-O-XOO', 0), ('X-XOOXOX-X-O-XOO', (2, 0), 'X-XOOXOXOX-O-XOO', -1)]
# [('---------------O', (1, 3), '-------X-------O', 0), ('-------X------OO', (2, 1), '-------X-X----OO', 0), ('------OX-X----OO', (0, 0), 'X-----OX-X----OO', 0), ('X---O-OX-X----OO', (0, 2), 'X-X-O-OX-X----OO', 0), ('X-XOO-OX-X----OO', (3, 1), 'X-XOO-OX-X---XOO', 0), ('X-XOO-OX-X-O-XOO', (1, 1), 'X-XOOXOX-X-O-XOO', 0), ('X-XOOXOXOX-O-XOO', (0, 1), 'XXXOOXOXOX-O-XOO', 1)]
# ----------------------------------------------------------------------------------------------------
# 8766:
# [('----------------', (3, 2), '--------------O-', 0), ('-----X--------O-', (2, 3), '-----X-----O--O-', 0), ('-X---X-----O--O-', (0, 2), '-XO--X-----O--O-', 0), ('-XO--X-----OX-O-', (1, 3), '-XO--X-O---OX-O-', 0), ('-XO--X-O-X-OX-O-', (2, 2), '-XO--X-O-XOOX-O-', 0), ('XXO--X-O-XOOX-O-', (0, 3), 'XXOO-X-O-XOOX-O-', 0), ('XXOOXX-O-XOOX-O-', (3, 1), 'XXOOXX-O-XOOXOO-', 0), ('XXOOXX-O-XOOXOOX', (2, 0), 'XXOOXX-OOXOOXOOX', 0)]
# [('--------------O-', (1, 1), '-----X--------O-', 0), ('-----X-----O--O-', (0, 1), '-X---X-----O--O-', 0), ('-XO--X-----O--O-', (3, 0), '-XO--X-----OX-O-', 0), ('-XO--X-O---OX-O-', (2, 1), '-XO--X-O-X-OX-O-', 0), ('-XO--X-O-XOOX-O-', (0, 0), 'XXO--X-O-XOOX-O-', 0), ('XXOO-X-O-XOOX-O-', (1, 0), 'XXOOXX-O-XOOX-O-', 0), ('XXOOXX-O-XOOXOO-', (3, 3), 'XXOOXX-O-XOOXOOX', 0), ('XXOOXX-OOXOOXOOX', (1, 2), 'XXOOXXXOOXOOXOOX', 0)]
# ----------------------------------------------------------------------------------------------------
# 8767:
# [('----------------', (2, 3), '-----------O----', 0), ('----X------O----', (2, 2), '----X-----OO----', 0), ('----X-----OO--X-', (2, 0), '----X---O-OO--X-', 0), ('-X--X---O-OO--X-', (0, 0), 'OX--X---O-OO--X-', 0), ('OX-XX---O-OO--X-', (3, 0), 'OX-XX---O-OOO-X-', 0), ('OXXXX---O-OOO-X-', (1, 2), 'OXXXX-O-O-OOO-X-', 0), ('OXXXX-O-O-OOOXX-', (1, 1), 'OXXXXOO-O-OOOXX-', 0), ('OXXXXOO-OXOOOXX-', (3, 3), 'OXXXXOO-OXOOOXXO', 1)]
# [('-----------O----', (1, 0), '----X------O----', 0), ('----X-----OO----', (3, 2), '----X-----OO--X-', 0), ('----X---O-OO--X-', (0, 1), '-X--X---O-OO--X-', 0), ('OX--X---O-OO--X-', (0, 3), 'OX-XX---O-OO--X-', 0), ('OX-XX---O-OOO-X-', (0, 2), 'OXXXX---O-OOO-X-', 0), ('OXXXX-O-O-OOO-X-', (3, 1), 'OXXXX-O-O-OOOXX-', 0), ('OXXXXOO-O-OOOXX-', (2, 1), 'OXXXXOO-OXOOOXX-', -1)]
# ----------------------------------------------------------------------------------------------------
# 8768:
# [('----------------', (1, 2), '------O---------', 0), ('------O-----X---', (0, 1), '-O----O-----X---', 0), ('-OX---O-----X---', (0, 0), 'OOX---O-----X---', 0), ('OOX---O-X---X---', (1, 0), 'OOX-O-O-X---X---', 0), ('OOX-O-O-X---X--X', (3, 1), 'OOX-O-O-X---XO-X', 0), ('OOX-O-OXX---XO-X', (2, 2), 'OOX-O-OXX-O-XO-X', 0), ('OOX-O-OXXXO-XO-X', (1, 1), 'OOX-OOOXXXO-XO-X', 0), ('OOXXOOOXXXO-XO-X', (2, 3), 'OOXXOOOXXXOOXO-X', 0)]
# [('------O---------', (3, 0), '------O-----X---', 0), ('-O----O-----X---', (0, 2), '-OX---O-----X---', 0), ('OOX---O-----X---', (2, 0), 'OOX---O-X---X---', 0), ('OOX-O-O-X---X---', (3, 3), 'OOX-O-O-X---X--X', 0), ('OOX-O-O-X---XO-X', (1, 3), 'OOX-O-OXX---XO-X', 0), ('OOX-O-OXX-O-XO-X', (2, 1), 'OOX-O-OXXXO-XO-X', 0), ('OOX-OOOXXXO-XO-X', (0, 3), 'OOXXOOOXXXO-XO-X', 0), ('OOXXOOOXXXOOXO-X', (3, 2), 'OOXXOOOXXXOOXOXX', 0)]
# ----------------------------------------------------------------------------------------------------
# 8769:
# [('----------------', (1, 1), '-----O----------', 0), ('-----O------X---', (2, 0), '-----O--O---X---', 0), ('-----O--O---X--X', (3, 1), '-----O--O---XO-X', 0), ('--X--O--O---XO-X', (2, 1), '--X--O--OO--XO-X', 0), ('-XX--O--OO--XO-X', (1, 0), '-XX-OO--OO--XO-X', 0), ('-XXXOO--OO--XO-X', (3, 2), '-XXXOO--OO--XOOX', -1)]
# [('-----O----------', (3, 0), '-----O------X---', 0), ('-----O--O---X---', (3, 3), '-----O--O---X--X', 0), ('-----O--O---XO-X', (0, 2), '--X--O--O---XO-X', 0), ('--X--O--OO--XO-X', (0, 1), '-XX--O--OO--XO-X', 0), ('-XX-OO--OO--XO-X', (0, 3), '-XXXOO--OO--XO-X', 0), ('-XXXOO--OO--XOOX', (0, 0), 'XXXXOO--OO--XOOX', 1)]
# ----------------------------------------------------------------------------------------------------
# 8770:
# [('----------------', (0, 0), 'O---------------', 0), ('O-------X-------', (1, 1), 'O----O--X-------', 0), ('O--X-O--X-------', (0, 1), 'OO-X-O--X-------', 0), ('OO-X-O--X--X----', (3, 2), 'OO-X-O--X--X--O-', 0), ('OOXX-O--X--X--O-', (2, 2), 'OOXX-O--X-OX--O-', 0), ('OOXX-O--X-OX--OX', (3, 1), 'OOXX-O--X-OX-OOX', 0), ('OOXX-O--XXOX-OOX', (1, 3), 'OOXX-O-OXXOX-OOX', 0), ('OOXXXO-OXXOX-OOX', (3, 0), 'OOXXXO-OXXOXOOOX', 0)]
# [('O---------------', (2, 0), 'O-------X-------', 0), ('O----O--X-------', (0, 3), 'O--X-O--X-------', 0), ('OO-X-O--X-------', (2, 3), 'OO-X-O--X--X----', 0), ('OO-X-O--X--X--O-', (0, 2), 'OOXX-O--X--X--O-', 0), ('OOXX-O--X-OX--O-', (3, 3), 'OOXX-O--X-OX--OX', 0), ('OOXX-O--X-OX-OOX', (2, 1), 'OOXX-O--XXOX-OOX', 0), ('OOXX-O-OXXOX-OOX', (1, 0), 'OOXXXO-OXXOX-OOX', 0), ('OOXXXO-OXXOXOOOX', (1, 2), 'OOXXXOXOXXOXOOOX', 0)]
# ----------------------------------------------------------------------------------------------------
# 8771:
# [('----------------', (3, 1), '-------------O--', 0), ('-----X-------O--', (3, 2), '-----X-------OO-', 0), ('X----X-------OO-', (3, 3), 'X----X-------OOO', 0), ('X----X--X----OOO', (2, 3), 'X----X--X--O-OOO', 0), ('XX---X--X--O-OOO', (1, 3), 'XX---X-OX--O-OOO', 0), ('XX---X-OX--OXOOO', (2, 2), 'XX---X-OX-OOXOOO', 0), ('XXX--X-OX-OOXOOO', (1, 2), 'XXX--XOOX-OOXOOO', 0), ('XXX--XOOXXOOXOOO', (1, 0), 'XXX-OXOOXXOOXOOO', -1)]
# [('-------------O--', (1, 1), '-----X-------O--', 0), ('-----X-------OO-', (0, 0), 'X----X-------OO-', 0), ('X----X-------OOO', (2, 0), 'X----X--X----OOO', 0), ('X----X--X--O-OOO', (0, 1), 'XX---X--X--O-OOO', 0), ('XX---X-OX--O-OOO', (3, 0), 'XX---X-OX--OXOOO', 0), ('XX---X-OX-OOXOOO', (0, 2), 'XXX--X-OX-OOXOOO', 0), ('XXX--XOOX-OOXOOO', (2, 1), 'XXX--XOOXXOOXOOO', 0), ('XXX-OXOOXXOOXOOO', (0, 3), 'XXXXOXOOXXOOXOOO', 1)]
# ----------------------------------------------------------------------------------------------------
# 8772:
# [('----------------', (2, 0), '--------O-------', 0), ('--------O-----X-', (3, 1), '--------O----OX-', 0), ('-------XO----OX-', (0, 2), '--O----XO----OX-', 0), ('--O----XOX---OX-', (1, 2), '--O---OXOX---OX-', 0), ('-XO---OXOX---OX-', (1, 0), '-XO-O-OXOX---OX-', 0), ('XXO-O-OXOX---OX-', (3, 3), 'XXO-O-OXOX---OXO', 0), ('XXO-OXOXOX---OXO', (2, 3), 'XXO-OXOXOX-O-OXO', 0), ('XXO-OXOXOXXO-OXO', (3, 0), 'XXO-OXOXOXXOOOXO', 0)]
# [('--------O-------', (3, 2), '--------O-----X-', 0), ('--------O----OX-', (1, 3), '-------XO----OX-', 0), ('--O----XO----OX-', (2, 1), '--O----XOX---OX-', 0), ('--O---OXOX---OX-', (0, 1), '-XO---OXOX---OX-', 0), ('-XO-O-OXOX---OX-', (0, 0), 'XXO-O-OXOX---OX-', 0), ('XXO-O-OXOX---OXO', (1, 1), 'XXO-OXOXOX---OXO', 0), ('XXO-OXOXOX-O-OXO', (2, 2), 'XXO-OXOXOXXO-OXO', 0), ('XXO-OXOXOXXOOOXO', (0, 3), 'XXOXOXOXOXXOOOXO', 0)]
# ----------------------------------------------------------------------------------------------------
# 8773:
# [('----------------', (2, 1), '---------O------', 0), ('----X----O------', (0, 0), 'O---X----O------', 0), ('O--XX----O------', (0, 2), 'O-OXX----O------', 0), ('O-OXX----O---X--', (3, 3), 'O-OXX----O---X-O', 0), ('OXOXX----O---X-O', (2, 3), 'OXOXX----O-O-X-O', 0), ('OXOXX---XO-O-X-O', (1, 3), 'OXOXX--OXO-O-X-O', 0), ('OXOXX--OXO-O-XXO', (1, 2), 'OXOXX-OOXO-O-XXO', 0), ('OXOXX-OOXOXO-XXO', (3, 0), 'OXOXX-OOXOXOOXXO', 0)]
# [('---------O------', (1, 0), '----X----O------', 0), ('O---X----O------', (0, 3), 'O--XX----O------', 0), ('O-OXX----O------', (3, 1), 'O-OXX----O---X--', 0), ('O-OXX----O---X-O', (0, 1), 'OXOXX----O---X-O', 0), ('OXOXX----O-O-X-O', (2, 0), 'OXOXX---XO-O-X-O', 0), ('OXOXX--OXO-O-X-O', (3, 2), 'OXOXX--OXO-O-XXO', 0), ('OXOXX-OOXO-O-XXO', (2, 2), 'OXOXX-OOXOXO-XXO', 0), ('OXOXX-OOXOXOOXXO', (1, 1), 'OXOXXXOOXOXOOXXO', 0)]
# ----------------------------------------------------------------------------------------------------
# 8774:
# [('----------------', (1, 0), '----O-----------', 0), ('----O-------X---', (3, 1), '----O-------XO--', 0), ('--X-O-------XO--', (2, 1), '--X-O----O--XO--', 0), ('--X-O---XO--XO--', (3, 2), '--X-O---XO--XOO-', 0), ('-XX-O---XO--XOO-', (1, 2), '-XX-O-O-XO--XOO-', 0), ('-XX-O-OXXO--XOO-', (1, 1), '-XX-OOOXXO--XOO-', 0), ('-XX-OOOXXOX-XOO-', (2, 3), '-XX-OOOXXOXOXOO-', 0), ('XXX-OOOXXOXOXOO-', (3, 3), 'XXX-OOOXXOXOXOOO', -1)]
# [('----O-----------', (3, 0), '----O-------X---', 0), ('----O-------XO--', (0, 2), '--X-O-------XO--', 0), ('--X-O----O--XO--', (2, 0), '--X-O---XO--XO--', 0), ('--X-O---XO--XOO-', (0, 1), '-XX-O---XO--XOO-', 0), ('-XX-O-O-XO--XOO-', (1, 3), '-XX-O-OXXO--XOO-', 0), ('-XX-OOOXXO--XOO-', (2, 2), '-XX-OOOXXOX-XOO-', 0), ('-XX-OOOXXOXOXOO-', (0, 0), 'XXX-OOOXXOXOXOO-', 0), ('XXX-OOOXXOXOXOOO', (0, 3), 'XXXXOOOXXOXOXOOO', 1)]
# ----------------------------------------------------------------------------------------------------
# 8775:
# [('----------------', (0, 0), 'O---------------', 0), ('O-X-------------', (1, 1), 'O-X--O----------', 0), ('O-X--O-------X--', (3, 0), 'O-X--O------OX--', 0), ('O-X-XO------OX--', (3, 3), 'O-X-XO------OX-O', 0), ('O-XXXO------OX-O', (2, 1), 'O-XXXO---O--OX-O', 0), ('O-XXXO--XO--OX-O', (0, 1), 'OOXXXO--XO--OX-O', 0), ('OOXXXO-XXO--OX-O', (3, 2), 'OOXXXO-XXO--OXOO', 0), ('OOXXXO-XXOX-OXOO', (2, 3), 'OOXXXO-XXOXOOXOO', 0)]
# [('O---------------', (0, 2), 'O-X-------------', 0), ('O-X--O----------', (3, 1), 'O-X--O-------X--', 0), ('O-X--O------OX--', (1, 0), 'O-X-XO------OX--', 0), ('O-X-XO------OX-O', (0, 3), 'O-XXXO------OX-O', 0), ('O-XXXO---O--OX-O', (2, 0), 'O-XXXO--XO--OX-O', 0), ('OOXXXO--XO--OX-O', (1, 3), 'OOXXXO-XXO--OX-O', 0), ('OOXXXO-XXO--OXOO', (2, 2), 'OOXXXO-XXOX-OXOO', 0), ('OOXXXO-XXOXOOXOO', (1, 2), 'OOXXXOXXXOXOOXOO', 0)]
# ----------------------------------------------------------------------------------------------------
# 8776:
# [('----------------', (2, 1), '---------O------', 0), ('---------O--X---', (3, 1), '---------O--XO--', 0), ('------X--O--XO--', (3, 2), '------X--O--XOO-', 0), ('------X--OX-XOO-', (3, 3), '------X--OX-XOOO', 0), ('--X---X--OX-XOOO', (1, 1), '--X--OX--OX-XOOO', 0), ('--X--OX--OXXXOOO', (2, 0), '--X--OX-OOXXXOOO', 0), ('--X--OXXOOXXXOOO', (0, 3), '--XO-OXXOOXXXOOO', 0), ('-XXO-OXXOOXXXOOO', (1, 0), '-XXOOOXXOOXXXOOO', 0)]
# [('---------O------', (3, 0), '---------O--X---', 0), ('---------O--XO--', (1, 2), '------X--O--XO--', 0), ('------X--O--XOO-', (2, 2), '------X--OX-XOO-', 0), ('------X--OX-XOOO', (0, 2), '--X---X--OX-XOOO', 0), ('--X--OX--OX-XOOO', (2, 3), '--X--OX--OXXXOOO', 0), ('--X--OX-OOXXXOOO', (1, 3), '--X--OXXOOXXXOOO', 0), ('--XO-OXXOOXXXOOO', (0, 1), '-XXO-OXXOOXXXOOO', 0), ('-XXOOOXXOOXXXOOO', (0, 0), 'XXXOOOXXOOXXXOOO', 0)]
# ----------------------------------------------------------------------------------------------------
# 8777:
# [('----------------', (1, 3), '-------O--------', 0), ('-------OX-------', (2, 1), '-------OXO------', 0), ('-------OXOX-----', (1, 0), '----O--OXOX-----', 0), ('---XO--OXOX-----', (2, 3), '---XO--OXOXO----', 0), ('---XO--OXOXO--X-', (0, 2), '--OXO--OXOXO--X-', 0), ('--OXO-XOXOXO--X-', (3, 1), '--OXO-XOXOXO-OX-', 0), ('-XOXO-XOXOXO-OX-', (3, 3), '-XOXO-XOXOXO-OXO', 0), ('-XOXOXXOXOXO-OXO', (0, 0), 'OXOXOXXOXOXO-OXO', 0)]
# [('-------O--------', (2, 0), '-------OX-------', 0), ('-------OXO------', (2, 2), '-------OXOX-----', 0), ('----O--OXOX-----', (0, 3), '---XO--OXOX-----', 0), ('---XO--OXOXO----', (3, 2), '---XO--OXOXO--X-', 0), ('--OXO--OXOXO--X-', (1, 2), '--OXO-XOXOXO--X-', 0), ('--OXO-XOXOXO-OX-', (0, 1), '-XOXO-XOXOXO-OX-', 0), ('-XOXO-XOXOXO-OXO', (1, 1), '-XOXOXXOXOXO-OXO', 0), ('OXOXOXXOXOXO-OXO', (3, 0), 'OXOXOXXOXOXOXOXO', 0)]
# ----------------------------------------------------------------------------------------------------
# 8778:
# [('----------------', (3, 2), '--------------O-', 0), ('------X-------O-', (0, 2), '--O---X-------O-', 0), ('--O---X----X--O-', (0, 3), '--OO--X----X--O-', 0), ('--OOX-X----X--O-', (0, 0), 'O-OOX-X----X--O-', 0), ('O-OOX-X-X--X--O-', (3, 3), 'O-OOX-X-X--X--OO', 0), ('O-OOX-X-X-XX--OO', (1, 3), 'O-OOX-XOX-XX--OO', -1)]
# [('--------------O-', (1, 2), '------X-------O-', 0), ('--O---X-------O-', (2, 3), '--O---X----X--O-', 0), ('--OO--X----X--O-', (1, 0), '--OOX-X----X--O-', 0), ('O-OOX-X----X--O-', (2, 0), 'O-OOX-X-X--X--O-', 0), ('O-OOX-X-X--X--OO', (2, 2), 'O-OOX-X-X-XX--OO', 0), ('O-OOX-XOX-XX--OO', (2, 1), 'O-OOX-XOXXXX--OO', 1)]
# ----------------------------------------------------------------------------------------------------
# 8779:
# [('----------------', (0, 0), 'O---------------', 0), ('O----------X----', (1, 0), 'O---O------X----', 0), ('O---O------X--X-', (3, 0), 'O---O------XO-X-', 0), ('O---O--X---XO-X-', (1, 2), 'O---O-OX---XO-X-', 0), ('O---O-OX-X-XO-X-', (1, 1), 'O---OOOX-X-XO-X-', 0), ('O-X-OOOX-X-XO-X-', (0, 3), 'O-XOOOOX-X-XO-X-', 0), ('O-XOOOOX-X-XOXX-', (0, 1), 'OOXOOOOX-X-XOXX-', 0), ('OOXOOOOX-X-XOXXX', (2, 0), 'OOXOOOOXOX-XOXXX', 1)]
# [('O---------------', (2, 3), 'O----------X----', 0), ('O---O------X----', (3, 2), 'O---O------X--X-', 0), ('O---O------XO-X-', (1, 3), 'O---O--X---XO-X-', 0), ('O---O-OX---XO-X-', (2, 1), 'O---O-OX-X-XO-X-', 0), ('O---OOOX-X-XO-X-', (0, 2), 'O-X-OOOX-X-XO-X-', 0), ('O-XOOOOX-X-XO-X-', (3, 1), 'O-XOOOOX-X-XOXX-', 0), ('OOXOOOOX-X-XOXX-', (3, 3), 'OOXOOOOX-X-XOXXX', -1)]
# ----------------------------------------------------------------------------------------------------
# 8780:
# [('----------------', (1, 0), '----O-----------', 0), ('----O--------X--', (0, 1), '-O--O--------X--', 0), ('-O--OX-------X--', (2, 3), '-O--OX-----O-X--', 0), ('-O--OX-X---O-X--', (2, 2), '-O--OX-X--OO-X--', 0), ('-O--OX-X--OO-XX-', (3, 0), '-O--OX-X--OOOXX-', 0), ('XO--OX-X--OOOXX-', (3, 3), 'XO--OX-X--OOOXXO', 0), ('XO--OX-X-XOOOXXO', (0, 2), 'XOO-OX-X-XOOOXXO', 0), ('XOO-OXXX-XOOOXXO', (0, 3), 'XOOOOXXX-XOOOXXO', 0)]
# [('----O-----------', (3, 1), '----O--------X--', 0), ('-O--O--------X--', (1, 1), '-O--OX-------X--', 0), ('-O--OX-----O-X--', (1, 3), '-O--OX-X---O-X--', 0), ('-O--OX-X--OO-X--', (3, 2), '-O--OX-X--OO-XX-', 0), ('-O--OX-X--OOOXX-', (0, 0), 'XO--OX-X--OOOXX-', 0), ('XO--OX-X--OOOXXO', (2, 1), 'XO--OX-X-XOOOXXO', 0), ('XOO-OX-X-XOOOXXO', (1, 2), 'XOO-OXXX-XOOOXXO', 0), ('XOOOOXXX-XOOOXXO', (2, 0), 'XOOOOXXXXXOOOXXO', 0)]
# ----------------------------------------------------------------------------------------------------
# 8781:
# [('----------------', (1, 0), '----O-----------', 0), ('X---O-----------', (0, 1), 'XO--O-----------', 0), ('XO--O---------X-', (3, 3), 'XO--O---------XO', 0), ('XO--O-X-------XO', (2, 0), 'XO--O-X-O-----XO', 0), ('XO-XO-X-O-----XO', (3, 0), 'XO-XO-X-O---O-XO', 0), ('XO-XO-X-O---OXXO', (2, 2), 'XO-XO-X-O-O-OXXO', 0), ('XO-XO-X-O-OXOXXO', (0, 2), 'XOOXO-X-O-OXOXXO', 0), ('XOOXO-XXO-OXOXXO', (1, 1), 'XOOXOOXXO-OXOXXO', 0)]
# [('----O-----------', (0, 0), 'X---O-----------', 0), ('XO--O-----------', (3, 2), 'XO--O---------X-', 0), ('XO--O---------XO', (1, 2), 'XO--O-X-------XO', 0), ('XO--O-X-O-----XO', (0, 3), 'XO-XO-X-O-----XO', 0), ('XO-XO-X-O---O-XO', (3, 1), 'XO-XO-X-O---OXXO', 0), ('XO-XO-X-O-O-OXXO', (2, 3), 'XO-XO-X-O-OXOXXO', 0), ('XOOXO-X-O-OXOXXO', (1, 3), 'XOOXO-XXO-OXOXXO', 0), ('XOOXOOXXO-OXOXXO', (2, 1), 'XOOXOOXXOXOXOXXO', 0)]
# ----------------------------------------------------------------------------------------------------
# 8782:
# [('----------------', (3, 2), '--------------O-', 0), ('-----X--------O-', (0, 3), '---O-X--------O-', 0), ('---O-X------X-O-', (2, 2), '---O-X----O-X-O-', 0), ('---O-XX---O-X-O-', (3, 1), '---O-XX---O-XOO-', 0), ('---O-XXX--O-XOO-', (0, 1), '-O-O-XXX--O-XOO-', 0), ('-OXO-XXX--O-XOO-', (2, 0), '-OXO-XXXO-O-XOO-', 0), ('XOXO-XXXO-O-XOO-', (2, 3), 'XOXO-XXXO-OOXOO-', -1)]
# [('--------------O-', (1, 1), '-----X--------O-', 0), ('---O-X--------O-', (3, 0), '---O-X------X-O-', 0), ('---O-X----O-X-O-', (1, 2), '---O-XX---O-X-O-', 0), ('---O-XX---O-XOO-', (1, 3), '---O-XXX--O-XOO-', 0), ('-O-O-XXX--O-XOO-', (0, 2), '-OXO-XXX--O-XOO-', 0), ('-OXO-XXXO-O-XOO-', (0, 0), 'XOXO-XXXO-O-XOO-', 0), ('XOXO-XXXO-OOXOO-', (1, 0), 'XOXOXXXXO-OOXOO-', 1)]
# ----------------------------------------------------------------------------------------------------
# 8783:
# [('----------------', (2, 3), '-----------O----', 0), ('-----------O-X--', (0, 2), '--O--------O-X--', 0), ('--O--------O-XX-', (1, 2), '--O---O----O-XX-', 0), ('X-O---O----O-XX-', (0, 1), 'XOO---O----O-XX-', 0), ('XOO---O---XO-XX-', (0, 3), 'XOOO--O---XO-XX-', 0), ('XOOO--O--XXO-XX-', (1, 1), 'XOOO-OO--XXO-XX-', 0), ('XOOO-OO-XXXO-XX-', (1, 0), 'XOOOOOO-XXXO-XX-', 0), ('XOOOOOOXXXXO-XX-', (3, 3), 'XOOOOOOXXXXO-XXO', 0)]
# [('-----------O----', (3, 1), '-----------O-X--', 0), ('--O--------O-X--', (3, 2), '--O--------O-XX-', 0), ('--O---O----O-XX-', (0, 0), 'X-O---O----O-XX-', 0), ('XOO---O----O-XX-', (2, 2), 'XOO---O---XO-XX-', 0), ('XOOO--O---XO-XX-', (2, 1), 'XOOO--O--XXO-XX-', 0), ('XOOO-OO--XXO-XX-', (2, 0), 'XOOO-OO-XXXO-XX-', 0), ('XOOOOOO-XXXO-XX-', (1, 3), 'XOOOOOOXXXXO-XX-', 0), ('XOOOOOOXXXXO-XXO', (3, 0), 'XOOOOOOXXXXOXXXO', 0)]
# ----------------------------------------------------------------------------------------------------
# 8784:
# [('----------------', (0, 1), '-O--------------', 0), ('-O------X-------', (0, 0), 'OO------X-------', 0), ('OO------X-X-----', (2, 1), 'OO------XOX-----', 0), ('OO------XOX-X---', (3, 2), 'OO------XOX-X-O-', 0), ('OO----X-XOX-X-O-', (3, 1), 'OO----X-XOX-XOO-', 0), ('OO----X-XOX-XOOX', (1, 1), 'OO---OX-XOX-XOOX', 1)]
# [('-O--------------', (2, 0), '-O------X-------', 0), ('OO------X-------', (2, 2), 'OO------X-X-----', 0), ('OO------XOX-----', (3, 0), 'OO------XOX-X---', 0), ('OO------XOX-X-O-', (1, 2), 'OO----X-XOX-X-O-', 0), ('OO----X-XOX-XOO-', (3, 3), 'OO----X-XOX-XOOX', -1)]
# ----------------------------------------------------------------------------------------------------
# 8785:
# [('----------------', (2, 3), '-----------O----', 0), ('------X----O----', (3, 0), '------X----OO---', 0), ('X-----X----OO---', (1, 3), 'X-----XO---OO---', 0), ('X--X--XO---OO---', (3, 1), 'X--X--XO---OOO--', 0), ('X--X-XXO---OOO--', (3, 2), 'X--X-XXO---OOOO-', 0), ('X--XXXXO---OOOO-', (3, 3), 'X--XXXXO---OOOOO', 1)]
# [('-----------O----', (1, 2), '------X----O----', 0), ('------X----OO---', (0, 0), 'X-----X----OO---', 0), ('X-----XO---OO---', (0, 3), 'X--X--XO---OO---', 0), ('X--X--XO---OOO--', (1, 1), 'X--X-XXO---OOO--', 0), ('X--X-XXO---OOOO-', (1, 0), 'X--XXXXO---OOOO-', -1)]
# ----------------------------------------------------------------------------------------------------
# 8786:
# [('----------------', (1, 0), '----O-----------', 0), ('----O--------X--', (2, 3), '----O------O-X--', 0), ('----O-----XO-X--', (3, 2), '----O-----XO-XO-', 0), ('-X--O-----XO-XO-', (0, 0), 'OX--O-----XO-XO-', 0), ('OX--O--X--XO-XO-', (0, 2), 'OXO-O--X--XO-XO-', 0), ('OXO-O--X-XXO-XO-', (2, 0), 'OXO-O--XOXXO-XO-', 0), ('OXO-O-XXOXXO-XO-', (3, 3), 'OXO-O-XXOXXO-XOO', 0), ('OXO-O-XXOXXOXXOO', (0, 3), 'OXOOO-XXOXXOXXOO', -1)]
# [('----O-----------', (3, 1), '----O--------X--', 0), ('----O------O-X--', (2, 2), '----O-----XO-X--', 0), ('----O-----XO-XO-', (0, 1), '-X--O-----XO-XO-', 0), ('OX--O-----XO-XO-', (1, 3), 'OX--O--X--XO-XO-', 0), ('OXO-O--X--XO-XO-', (2, 1), 'OXO-O--X-XXO-XO-', 0), ('OXO-O--XOXXO-XO-', (1, 2), 'OXO-O-XXOXXO-XO-', 0), ('OXO-O-XXOXXO-XOO', (3, 0), 'OXO-O-XXOXXOXXOO', 0), ('OXOOO-XXOXXOXXOO', (1, 1), 'OXOOOXXXOXXOXXOO', 1)]
# ----------------------------------------------------------------------------------------------------
# 8787:
# [('----------------', (3, 3), '---------------O', 0), ('-------X-------O', (3, 1), '-------X-----O-O', 0), ('X------X-----O-O', (2, 0), 'X------XO----O-O', 0), ('X-X----XO----O-O', (2, 2), 'X-X----XO-O--O-O', 0), ('XXX----XO-O--O-O', (1, 2), 'XXX---OXO-O--O-O', 0), ('XXX---OXO-O-XO-O', (1, 1), 'XXX--OOXO-O-XO-O', 0), ('XXX--OOXO-O-XOXO', (0, 3), 'XXXO-OOXO-O-XOXO', 0), ('XXXOXOOXO-O-XOXO', (2, 3), 'XXXOXOOXO-OOXOXO', 0)]
# [('---------------O', (1, 3), '-------X-------O', 0), ('-------X-----O-O', (0, 0), 'X------X-----O-O', 0), ('X------XO----O-O', (0, 2), 'X-X----XO----O-O', 0), ('X-X----XO-O--O-O', (0, 1), 'XXX----XO-O--O-O', 0), ('XXX---OXO-O--O-O', (3, 0), 'XXX---OXO-O-XO-O', 0), ('XXX--OOXO-O-XO-O', (3, 2), 'XXX--OOXO-O-XOXO', 0), ('XXXO-OOXO-O-XOXO', (1, 0), 'XXXOXOOXO-O-XOXO', 0), ('XXXOXOOXO-OOXOXO', (2, 1), 'XXXOXOOXOXOOXOXO', 0)]
# ----------------------------------------------------------------------------------------------------
# 8788:
# [('----------------', (2, 2), '----------O-----', 0), ('----------O--X--', (2, 1), '---------OO--X--', 0), ('-------X-OO--X--', (1, 0), '----O--X-OO--X--', 0), ('----O--X-OO--X-X', (1, 2), '----O-OX-OO--X-X', 0), ('----OXOX-OO--X-X', (0, 0), 'O---OXOX-OO--X-X', 0), ('O---OXOX-OOX-X-X', (2, 0), 'O---OXOXOOOX-X-X', 0), ('O-X-OXOXOOOX-X-X', (0, 3), 'O-XOOXOXOOOX-X-X', 0), ('O-XOOXOXOOOX-XXX', (3, 0), 'O-XOOXOXOOOXOXXX', 1)]
# [('----------O-----', (3, 1), '----------O--X--', 0), ('---------OO--X--', (1, 3), '-------X-OO--X--', 0), ('----O--X-OO--X--', (3, 3), '----O--X-OO--X-X', 0), ('----O-OX-OO--X-X', (1, 1), '----OXOX-OO--X-X', 0), ('O---OXOX-OO--X-X', (2, 3), 'O---OXOX-OOX-X-X', 0), ('O---OXOXOOOX-X-X', (0, 2), 'O-X-OXOXOOOX-X-X', 0), ('O-XOOXOXOOOX-X-X', (3, 2), 'O-XOOXOXOOOX-XXX', -1)]
# ----------------------------------------------------------------------------------------------------
# 8789:
# [('----------------', (0, 3), '---O------------', 0), ('---O-----X------', (3, 1), '---O-----X---O--', 0), ('---O-X---X---O--', (0, 1), '-O-O-X---X---O--', 0), ('-OXO-X---X---O--', (1, 2), '-OXO-XO--X---O--', 0), ('-OXO-XO--X-X-O--', (1, 3), '-OXO-XOO-X-X-O--', 0), ('-OXOXXOO-X-X-O--', (0, 0), 'OOXOXXOO-X-X-O--', 0), ('OOXOXXOOXX-X-O--', (3, 0), 'OOXOXXOOXX-XOO--', 0), ('OOXOXXOOXX-XOO-X', (3, 2), 'OOXOXXOOXX-XOOOX', -1)]
# [('---O------------', (2, 1), '---O-----X------', 0), ('---O-----X---O--', (1, 1), '---O-X---X---O--', 0), ('-O-O-X---X---O--', (0, 2), '-OXO-X---X---O--', 0), ('-OXO-XO--X---O--', (2, 3), '-OXO-XO--X-X-O--', 0), ('-OXO-XOO-X-X-O--', (1, 0), '-OXOXXOO-X-X-O--', 0), ('OOXOXXOO-X-X-O--', (2, 0), 'OOXOXXOOXX-X-O--', 0), ('OOXOXXOOXX-XOO--', (3, 3), 'OOXOXXOOXX-XOO-X', 0), ('OOXOXXOOXX-XOOOX', (2, 2), 'OOXOXXOOXXXXOOOX', 1)]
# ----------------------------------------------------------------------------------------------------
# 8790:
# [('----------------', (1, 2), '------O---------', 0), ('------O--X------', (0, 3), '---O--O--X------', 0), ('-X-O--O--X------', (2, 3), '-X-O--O--X-O----', 0), ('-X-O--O--X-O--X-', (2, 2), '-X-O--O--XOO--X-', 0), ('-X-O--O--XOO-XX-', (1, 1), '-X-O-OO--XOO-XX-', 0), ('-X-OXOO--XOO-XX-', (0, 0), 'OX-OXOO--XOO-XX-', 0), ('OX-OXOOX-XOO-XX-', (3, 0), 'OX-OXOOX-XOOOXX-', 0), ('OXXOXOOX-XOOOXX-', (3, 3), 'OXXOXOOX-XOOOXXO', 1)]
# [('------O---------', (2, 1), '------O--X------', 0), ('---O--O--X------', (0, 1), '-X-O--O--X------', 0), ('-X-O--O--X-O----', (3, 2), '-X-O--O--X-O--X-', 0), ('-X-O--O--XOO--X-', (3, 1), '-X-O--O--XOO-XX-', 0), ('-X-O-OO--XOO-XX-', (1, 0), '-X-OXOO--XOO-XX-', 0), ('OX-OXOO--XOO-XX-', (1, 3), 'OX-OXOOX-XOO-XX-', 0), ('OX-OXOOX-XOOOXX-', (0, 2), 'OXXOXOOX-XOOOXX-', -1)]
# ----------------------------------------------------------------------------------------------------
# 8791:
# [('----------------', (3, 2), '--------------O-', 0), ('---X----------O-', (1, 2), '---X--O-------O-', 0), ('---X-XO-------O-', (0, 0), 'O--X-XO-------O-', 0), ('O--X-XO----X--O-', (2, 2), 'O--X-XO---OX--O-', 0), ('OX-X-XO---OX--O-', (1, 3), 'OX-X-XOO--OX--O-', 0), ('OX-X-XOOX-OX--O-', (0, 2), 'OXOX-XOOX-OX--O-', 1)]
# [('--------------O-', (0, 3), '---X----------O-', 0), ('---X--O-------O-', (1, 1), '---X-XO-------O-', 0), ('O--X-XO-------O-', (2, 3), 'O--X-XO----X--O-', 0), ('O--X-XO---OX--O-', (0, 1), 'OX-X-XO---OX--O-', 0), ('OX-X-XOO--OX--O-', (2, 0), 'OX-X-XOOX-OX--O-', -1)]
# ----------------------------------------------------------------------------------------------------
# 8792:
# [('----------------', (2, 2), '----------O-----', 0), ('----------O--X--', (2, 0), '--------O-O--X--', 0), ('------X-O-O--X--', (3, 3), '------X-O-O--X-O', 0), ('----X-X-O-O--X-O', (2, 1), '----X-X-OOO--X-O', 0), ('----X-X-OOOX-X-O', (3, 2), '----X-X-OOOX-XOO', 0), ('----X-XXOOOX-XOO', (0, 0), 'O---X-XXOOOX-XOO', 0), ('OX--X-XXOOOX-XOO', (3, 0), 'OX--X-XXOOOXOXOO', -1)]
# [('----------O-----', (3, 1), '----------O--X--', 0), ('--------O-O--X--', (1, 2), '------X-O-O--X--', 0), ('------X-O-O--X-O', (1, 0), '----X-X-O-O--X-O', 0), ('----X-X-OOO--X-O', (2, 3), '----X-X-OOOX-X-O', 0), ('----X-X-OOOX-XOO', (1, 3), '----X-XXOOOX-XOO', 0), ('O---X-XXOOOX-XOO', (0, 1), 'OX--X-XXOOOX-XOO', 0), ('OX--X-XXOOOXOXOO', (1, 1), 'OX--XXXXOOOXOXOO', 1)]
# ----------------------------------------------------------------------------------------------------
# 8793:
# [('----------------', (0, 1), '-O--------------', 0), ('-O---------X----', (1, 3), '-O-----O---X----', 0), ('-O-----O--XX----', (2, 1), '-O-----O-OXX----', 0), ('-O---X-O-OXX----', (3, 1), '-O---X-O-OXX-O--', 0), ('-OX--X-O-OXX-O--', (3, 3), '-OX--X-O-OXX-O-O', 0), ('-OX-XX-O-OXX-O-O', (0, 3), '-OXOXX-O-OXX-O-O', 0), ('XOXOXX-O-OXX-O-O', (2, 0), 'XOXOXX-OOOXX-O-O', 0), ('XOXOXX-OOOXX-OXO', (1, 2), 'XOXOXXOOOOXX-OXO', 0)]
# [('-O--------------', (2, 3), '-O---------X----', 0), ('-O-----O---X----', (2, 2), '-O-----O--XX----', 0), ('-O-----O-OXX----', (1, 1), '-O---X-O-OXX----', 0), ('-O---X-O-OXX-O--', (0, 2), '-OX--X-O-OXX-O--', 0), ('-OX--X-O-OXX-O-O', (1, 0), '-OX-XX-O-OXX-O-O', 0), ('-OXOXX-O-OXX-O-O', (0, 0), 'XOXOXX-O-OXX-O-O', 0), ('XOXOXX-OOOXX-O-O', (3, 2), 'XOXOXX-OOOXX-OXO', 0), ('XOXOXXOOOOXX-OXO', (3, 0), 'XOXOXXOOOOXXXOXO', 0)]
# ----------------------------------------------------------------------------------------------------
# 8794:
# [('----------------', (3, 3), '---------------O', 0), ('---------X-----O', (3, 0), '---------X--O--O', 0), ('------X--X--O--O', (2, 3), '------X--X-OO--O', 0), ('---X--X--X-OO--O', (1, 0), '---XO-X--X-OO--O', 0), ('---XOXX--X-OO--O', (0, 1), '-O-XOXX--X-OO--O', 0), ('-O-XOXX--XXOO--O', (2, 0), '-O-XOXX-OXXOO--O', 0), ('-OXXOXX-OXXOO--O', (3, 1), '-OXXOXX-OXXOOO-O', 0), ('-OXXOXXXOXXOOO-O', (0, 0), 'OOXXOXXXOXXOOO-O', 1)]
# [('---------------O', (2, 1), '---------X-----O', 0), ('---------X--O--O', (1, 2), '------X--X--O--O', 0), ('------X--X-OO--O', (0, 3), '---X--X--X-OO--O', 0), ('---XO-X--X-OO--O', (1, 1), '---XOXX--X-OO--O', 0), ('-O-XOXX--X-OO--O', (2, 2), '-O-XOXX--XXOO--O', 0), ('-O-XOXX-OXXOO--O', (0, 2), '-OXXOXX-OXXOO--O', 0), ('-OXXOXX-OXXOOO-O', (1, 3), '-OXXOXXXOXXOOO-O', -1)]
# ----------------------------------------------------------------------------------------------------
# 8795:
# [('----------------', (0, 2), '--O-------------', 0), ('--O---X---------', (2, 0), '--O---X-O-------', 0), ('-XO---X-O-------', (3, 2), '-XO---X-O-----O-', 0), ('-XO---X-O-----OX', (1, 3), '-XO---XOO-----OX', 0), ('-XO--XXOO-----OX', (0, 0), 'OXO--XXOO-----OX', 0), ('OXO--XXOO-X---OX', (0, 3), 'OXOO-XXOO-X---OX', 0), ('OXOO-XXOOXX---OX', (3, 0), 'OXOO-XXOOXX-O-OX', 0), ('OXOOXXXOOXX-O-OX', (2, 3), 'OXOOXXXOOXXOO-OX', -1)]
# [('--O-------------', (1, 2), '--O---X---------', 0), ('--O---X-O-------', (0, 1), '-XO---X-O-------', 0), ('-XO---X-O-----O-', (3, 3), '-XO---X-O-----OX', 0), ('-XO---XOO-----OX', (1, 1), '-XO--XXOO-----OX', 0), ('OXO--XXOO-----OX', (2, 2), 'OXO--XXOO-X---OX', 0), ('OXOO-XXOO-X---OX', (2, 1), 'OXOO-XXOOXX---OX', 0), ('OXOO-XXOOXX-O-OX', (1, 0), 'OXOOXXXOOXX-O-OX', 0), ('OXOOXXXOOXXOO-OX', (3, 1), 'OXOOXXXOOXXOOXOX', 1)]
# ----------------------------------------------------------------------------------------------------
# 8796:
# [('----------------', (0, 3), '---O------------', 0), ('---O------X-----', (0, 2), '--OO------X-----', 0), ('--OO--X---X-----', (0, 0), 'O-OO--X---X-----', 0), ('O-OO--X---X-X---', (1, 0), 'O-OOO-X---X-X---', 0), ('O-OOO-X---X-X-X-', (0, 1), 'OOOOO-X---X-X-X-', 1)]
# [('---O------------', (2, 2), '---O------X-----', 0), ('--OO------X-----', (1, 2), '--OO--X---X-----', 0), ('O-OO--X---X-----', (3, 0), 'O-OO--X---X-X---', 0), ('O-OOO-X---X-X---', (3, 2), 'O-OOO-X---X-X-X-', -1)]
# ----------------------------------------------------------------------------------------------------
# 8797:
# [('----------------', (0, 3), '---O------------', 0), ('---O----X-------', (1, 3), '---O---OX-------', 0), ('---O---OX-X-----', (0, 2), '--OO---OX-X-----', 0), ('--OO---OX-X-X---', (3, 3), '--OO---OX-X-X--O', 0), ('--OO---OXXX-X--O', (1, 0), '--OOO--OXXX-X--O', 0), ('--OOOX-OXXX-X--O', (3, 2), '--OOOX-OXXX-X-OO', 0), ('--OOOX-OXXX-XXOO', (1, 2), '--OOOXOOXXX-XXOO', -1)]
# [('---O------------', (2, 0), '---O----X-------', 0), ('---O---OX-------', (2, 2), '---O---OX-X-----', 0), ('--OO---OX-X-----', (3, 0), '--OO---OX-X-X---', 0), ('--OO---OX-X-X--O', (2, 1), '--OO---OXXX-X--O', 0), ('--OOO--OXXX-X--O', (1, 1), '--OOOX-OXXX-X--O', 0), ('--OOOX-OXXX-X-OO', (3, 1), '--OOOX-OXXX-XXOO', 0), ('--OOOXOOXXX-XXOO', (0, 1), '-XOOOXOOXXX-XXOO', 1)]
# ----------------------------------------------------------------------------------------------------
# 8798:
# [('----------------', (0, 3), '---O------------', 0), ('---O-X----------', (2, 0), '---O-X--O-------', 0), ('---O-X--O--X----', (1, 2), '---O-XO-O--X----', 0), ('---O-XO-O--X-X--', (0, 0), 'O--O-XO-O--X-X--', 0), ('O--O-XO-O--X-X-X', (0, 2), 'O-OO-XO-O--X-X-X', 0), ('O-OO-XO-OX-X-X-X', (3, 0), 'O-OO-XO-OX-XOX-X', 0), ('O-OO-XO-OXXXOX-X', (1, 0), 'O-OOOXO-OXXXOX-X', 1)]
# [('---O------------', (1, 1), '---O-X----------', 0), ('---O-X--O-------', (2, 3), '---O-X--O--X----', 0), ('---O-XO-O--X----', (3, 1), '---O-XO-O--X-X--', 0), ('O--O-XO-O--X-X--', (3, 3), 'O--O-XO-O--X-X-X', 0), ('O-OO-XO-O--X-X-X', (2, 1), 'O-OO-XO-OX-X-X-X', 0), ('O-OO-XO-OX-XOX-X', (2, 2), 'O-OO-XO-OXXXOX-X', -1)]
# ----------------------------------------------------------------------------------------------------
# 8799:
# [('----------------', (2, 3), '-----------O----', 0), ('---X-------O----', (3, 2), '---X-------O--O-', 0), ('---X----X--O--O-', (3, 1), '---X----X--O-OO-', 0), ('---X----X--O-OOX', (0, 2), '--OX----X--O-OOX', 0), ('-XOX----X--O-OOX', (0, 0), 'OXOX----X--O-OOX', 0), ('OXOX----X--OXOOX', (1, 1), 'OXOX-O--X--OXOOX', 0), ('OXOXXO--X--OXOOX', (1, 2), 'OXOXXOO-X--OXOOX', 0), ('OXOXXOOXX--OXOOX', (2, 1), 'OXOXXOOXXO-OXOOX', 0)]
# [('-----------O----', (0, 3), '---X-------O----', 0), ('---X-------O--O-', (2, 0), '---X----X--O--O-', 0), ('---X----X--O-OO-', (3, 3), '---X----X--O-OOX', 0), ('--OX----X--O-OOX', (0, 1), '-XOX----X--O-OOX', 0), ('OXOX----X--O-OOX', (3, 0), 'OXOX----X--OXOOX', 0), ('OXOX-O--X--OXOOX', (1, 0), 'OXOXXO--X--OXOOX', 0), ('OXOXXOO-X--OXOOX', (1, 3), 'OXOXXOOXX--OXOOX', 0), ('OXOXXOOXXO-OXOOX', (2, 2), 'OXOXXOOXXOXOXOOX', 0)]
# ----------------------------------------------------------------------------------------------------
# 8800:
# [('----------------', (1, 2), '------O---------', 0), ('------O------X--', (2, 2), '------O---O--X--', 0), ('------O---O--X-X', (3, 0), '------O---O-OX-X', 0), ('X-----O---O-OX-X', (3, 2), 'X-----O---O-OXOX', 0), ('X-----O---OXOXOX', (0, 3), 'X--O--O---OXOXOX', 0), ('XX-O--O---OXOXOX', (2, 1), 'XX-O--O--OOXOXOX', 1)]
# [('------O---------', (3, 1), '------O------X--', 0), ('------O---O--X--', (3, 3), '------O---O--X-X', 0), ('------O---O-OX-X', (0, 0), 'X-----O---O-OX-X', 0), ('X-----O---O-OXOX', (2, 3), 'X-----O---OXOXOX', 0), ('X--O--O---OXOXOX', (0, 1), 'XX-O--O---OXOXOX', -1)]
# ----------------------------------------------------------------------------------------------------
# 8801:
# [('----------------', (2, 3), '-----------O----', 0), ('-----X-----O----', (2, 2), '-----X----OO----', 0), ('X----X----OO----', (0, 3), 'X--O-X----OO----', 0), ('X--OXX----OO----', (2, 0), 'X--OXX--O-OO----', 0), ('X--OXX--O-OOX---', (3, 3), 'X--OXX--O-OOX--O', 0), ('X--OXX-XO-OOX--O', (0, 2), 'X-OOXX-XO-OOX--O', -1)]
# [('-----------O----', (1, 1), '-----X-----O----', 0), ('-----X----OO----', (0, 0), 'X----X----OO----', 0), ('X--O-X----OO----', (1, 0), 'X--OXX----OO----', 0), ('X--OXX--O-OO----', (3, 0), 'X--OXX--O-OOX---', 0), ('X--OXX--O-OOX--O', (1, 3), 'X--OXX-XO-OOX--O', 0), ('X-OOXX-XO-OOX--O', (1, 2), 'X-OOXXXXO-OOX--O', 1)]
# ----------------------------------------------------------------------------------------------------
# 8802:
# [('----------------', (1, 2), '------O---------', 0), ('---X--O---------', (3, 3), '---X--O--------O', 0), ('---XX-O--------O', (1, 1), '---XXOO--------O', 0), ('--XXXOO--------O', (3, 0), '--XXXOO-----O--O', 0), ('--XXXOO---X-O--O', (3, 2), '--XXXOO---X-O-OO', 0), ('-XXXXOO---X-O-OO', (1, 3), '-XXXXOOO--X-O-OO', 0), ('-XXXXOOO-XX-O-OO', (3, 1), '-XXXXOOO-XX-OOOO', 1)]
# [('------O---------', (0, 3), '---X--O---------', 0), ('---X--O--------O', (1, 0), '---XX-O--------O', 0), ('---XXOO--------O', (0, 2), '--XXXOO--------O', 0), ('--XXXOO-----O--O', (2, 2), '--XXXOO---X-O--O', 0), ('--XXXOO---X-O-OO', (0, 1), '-XXXXOO---X-O-OO', 0), ('-XXXXOOO--X-O-OO', (2, 1), '-XXXXOOO-XX-O-OO', -1)]
# ----------------------------------------------------------------------------------------------------
# 8803:
# [('----------------', (1, 1), '-----O----------', 0), ('-----O---X------', (2, 0), '-----O--OX------', 0), ('-----O--OXX-----', (3, 0), '-----O--OXX-O---', 0), ('----XO--OXX-O---', (0, 2), '--O-XO--OXX-O---', 0), ('--O-XO--OXX-O-X-', (1, 3), '--O-XO-OOXX-O-X-', 0), ('--O-XOXOOXX-O-X-', (3, 1), '--O-XOXOOXX-OOX-', 0), ('--O-XOXOOXXXOOX-', (0, 3), '--OOXOXOOXXXOOX-', 0), ('-XOOXOXOOXXXOOX-', (3, 3), '-XOOXOXOOXXXOOXO', 0)]
# [('-----O----------', (2, 1), '-----O---X------', 0), ('-----O--OX------', (2, 2), '-----O--OXX-----', 0), ('-----O--OXX-O---', (1, 0), '----XO--OXX-O---', 0), ('--O-XO--OXX-O---', (3, 2), '--O-XO--OXX-O-X-', 0), ('--O-XO-OOXX-O-X-', (1, 2), '--O-XOXOOXX-O-X-', 0), ('--O-XOXOOXX-OOX-', (2, 3), '--O-XOXOOXXXOOX-', 0), ('--OOXOXOOXXXOOX-', (0, 1), '-XOOXOXOOXXXOOX-', 0), ('-XOOXOXOOXXXOOXO', (0, 0), 'XXOOXOXOOXXXOOXO', 0)]
# ----------------------------------------------------------------------------------------------------
# 8804:
# ...
# [('O---------------', (0, 3), 'O--X------------', 0), ('O-OX------------', (1, 0), 'O-OXX-----------', 0), ('O-OXX----O------', (3, 3), 'O-OXX----O-----X', 0), ('O-OXX----O-O---X', (2, 0), 'O-OXX---XO-O---X', 0), ('O-OXXO--XO-O---X', (0, 1), 'OXOXXO--XO-O---X', 0), ('OXOXXO--XO-O--OX', (1, 3), 'OXOXXO-XXO-O--OX', 0), ('OXOXXO-XXO-O-OOX', (1, 2), 'OXOXXOXXXO-O-OOX', 0), ('OXOXXOXXXOOO-OOX', (3, 0), 'OXOXXOXXXOOOXOOX', 0)]
# ----------------------------------------------------------------------------------------------------
# 9982:
# [('----------------', (1, 0), '----O-----------', 0), ('----O----------X', (3, 0), '----O-------O--X', 0), ('----O-------OX-X', (1, 1), '----OO------OX-X', 0), ('---XOO------OX-X', (2, 3), '---XOO-----OOX-X', 0), ('---XOO---X-OOX-X', (0, 0), 'O--XOO---X-OOX-X', 0), ('O--XOOX--X-OOX-X', (0, 1), 'OO-XOOX--X-OOX-X', 0), ('OO-XOOXX-X-OOX-X', (3, 2), 'OO-XOOXX-X-OOXOX', 0), ('OO-XOOXXXX-OOXOX', (2, 2), 'OO-XOOXXXXOOOXOX', 0)]
# [('----O-----------', (3, 3), '----O----------X', 0), ('----O-------O--X', (3, 1), '----O-------OX-X', 0), ('----OO------OX-X', (0, 3), '---XOO------OX-X', 0), ('---XOO-----OOX-X', (2, 1), '---XOO---X-OOX-X', 0), ('O--XOO---X-OOX-X', (1, 2), 'O--XOOX--X-OOX-X', 0), ('OO-XOOX--X-OOX-X', (1, 3), 'OO-XOOXX-X-OOX-X', 0), ('OO-XOOXX-X-OOXOX', (2, 0), 'OO-XOOXXXX-OOXOX', 0), ('OO-XOOXXXXOOOXOX', (0, 2), 'OOXXOOXXXXOOOXOX', 0)]
# ----------------------------------------------------------------------------------------------------
# 9983:
# [('----------------', (3, 0), '------------O---', 0), ('----------X-O---', (3, 1), '----------X-OO--', 0), ('----------XXOO--', (0, 1), '-O--------XXOO--', 0), ('-O------X-XXOO--', (0, 3), '-O-O----X-XXOO--', 0), ('-O-OX---X-XXOO--', (1, 2), '-O-OX-O-X-XXOO--', -1)]
# [('------------O---', (2, 2), '----------X-O---', 0), ('----------X-OO--', (2, 3), '----------XXOO--', 0), ('-O--------XXOO--', (2, 0), '-O------X-XXOO--', 0), ('-O-O----X-XXOO--', (1, 0), '-O-OX---X-XXOO--', 0), ('-O-OX-O-X-XXOO--', (2, 1), '-O-OX-O-XXXXOO--', 1)]
# ----------------------------------------------------------------------------------------------------
# 9984:
# [('----------------', (2, 3), '-----------O----', 0), ('-----------O--X-', (1, 3), '-------O---O--X-', 0), ('-------O---OX-X-', (1, 2), '------OO---OX-X-', 0), ('------OO-X-OX-X-', (3, 3), '------OO-X-OX-XO', 0), ('X-----OO-X-OX-XO', (2, 0), 'X-----OOOX-OX-XO', 0), ('X-----OOOXXOX-XO', (0, 2), 'X-O---OOOXXOX-XO', 0), ('X-OX--OOOXXOX-XO', (1, 1), 'X-OX-OOOOXXOX-XO', 0), ('X-OX-OOOOXXOXXXO', (0, 1), 'XOOX-OOOOXXOXXXO', 0)]
# [('-----------O----', (3, 2), '-----------O--X-', 0), ('-------O---O--X-', (3, 0), '-------O---OX-X-', 0), ('------OO---OX-X-', (2, 1), '------OO-X-OX-X-', 0), ('------OO-X-OX-XO', (0, 0), 'X-----OO-X-OX-XO', 0), ('X-----OOOX-OX-XO', (2, 2), 'X-----OOOXXOX-XO', 0), ('X-O---OOOXXOX-XO', (0, 3), 'X-OX--OOOXXOX-XO', 0), ('X-OX-OOOOXXOX-XO', (3, 1), 'X-OX-OOOOXXOXXXO', 0), ('XOOX-OOOOXXOXXXO', (1, 0), 'XOOXXOOOOXXOXXXO', 0)]
# ----------------------------------------------------------------------------------------------------
# 9985:
# [('----------------', (2, 0), '--------O-------', 0), ('X-------O-------', (0, 2), 'X-O-----O-------', 0), ('X-O-----O---X---', (1, 3), 'X-O----OO---X---', 0), ('X-O----OO---XX--', (1, 2), 'X-O---OOO---XX--', 0), ('X-O-X-OOO---XX--', (0, 1), 'XOO-X-OOO---XX--', 0), ('XOO-X-OOOX--XX--', (2, 3), 'XOO-X-OOOX-OXX--', 0), ('XOO-X-OOOX-OXXX-', (0, 3), 'XOOOX-OOOX-OXXX-', 0), ('XOOOX-OOOXXOXXX-', (1, 1), 'XOOOXOOOOXXOXXX-', -1)]
# [('--------O-------', (0, 0), 'X-------O-------', 0), ('X-O-----O-------', (3, 0), 'X-O-----O---X---', 0), ('X-O----OO---X---', (3, 1), 'X-O----OO---XX--', 0), ('X-O---OOO---XX--', (1, 0), 'X-O-X-OOO---XX--', 0), ('XOO-X-OOO---XX--', (2, 1), 'XOO-X-OOOX--XX--', 0), ('XOO-X-OOOX-OXX--', (3, 2), 'XOO-X-OOOX-OXXX-', 0), ('XOOOX-OOOX-OXXX-', (2, 2), 'XOOOX-OOOXXOXXX-', 0), ('XOOOXOOOOXXOXXX-', (3, 3), 'XOOOXOOOOXXOXXXX', 1)]
# ----------------------------------------------------------------------------------------------------
# 9986:
# [('----------------', (2, 0), '--------O-------', 0), ('--------O------X', (0, 2), '--O-----O------X', 0), ('--O-----O--X---X', (3, 1), '--O-----O--X-O-X', 0), ('--O-----OX-X-O-X', (2, 2), '--O-----OXOX-O-X', 0), ('--O-----OXOX-OXX', (0, 0), 'O-O-----OXOX-OXX', 0), ('O-OX----OXOX-OXX', (3, 0), 'O-OX----OXOXOOXX', -1)]
# [('--------O-------', (3, 3), '--------O------X', 0), ('--O-----O------X', (2, 3), '--O-----O--X---X', 0), ('--O-----O--X-O-X', (2, 1), '--O-----OX-X-O-X', 0), ('--O-----OXOX-O-X', (3, 2), '--O-----OXOX-OXX', 0), ('O-O-----OXOX-OXX', (0, 3), 'O-OX----OXOX-OXX', 0), ('O-OX----OXOXOOXX', (1, 3), 'O-OX---XOXOXOOXX', 1)]
# ----------------------------------------------------------------------------------------------------
# 9987:
# [('----------------', (0, 2), '--O-------------', 0), ('--O------------X', (1, 0), '--O-O----------X', 0), ('--O-O-----X----X', (1, 1), '--O-OO----X----X', 0), ('--O-OO-X--X----X', (0, 3), '--OOOO-X--X----X', 0), ('--OOOO-X--X-X--X', (3, 2), '--OOOO-X--X-X-OX', 0), ('--OOOO-X--XXX-OX', (1, 2), '--OOOOOX--XXX-OX', 0), ('X-OOOOOX--XXX-OX', (0, 1), 'XOOOOOOX--XXX-OX', 0), ('XOOOOOOX--XXXXOX', (2, 0), 'XOOOOOOXO-XXXXOX', 0)]
# [('--O-------------', (3, 3), '--O------------X', 0), ('--O-O----------X', (2, 2), '--O-O-----X----X', 0), ('--O-OO----X----X', (1, 3), '--O-OO-X--X----X', 0), ('--OOOO-X--X----X', (3, 0), '--OOOO-X--X-X--X', 0), ('--OOOO-X--X-X-OX', (2, 3), '--OOOO-X--XXX-OX', 0), ('--OOOOOX--XXX-OX', (0, 0), 'X-OOOOOX--XXX-OX', 0), ('XOOOOOOX--XXX-OX', (3, 1), 'XOOOOOOX--XXXXOX', 0), ('XOOOOOOXO-XXXXOX', (2, 1), 'XOOOOOOXOXXXXXOX', 0)]
# ----------------------------------------------------------------------------------------------------
# 9988:
# [('----------------', (2, 0), '--------O-------', 0), ('--------O------X', (3, 2), '--------O-----OX', 0), ('-------XO-----OX', (3, 0), '-------XO---O-OX', 0), ('------XXO---O-OX', (0, 0), 'O-----XXO---O-OX', 0), ('O-----XXO---OXOX', (1, 0), 'O---O-XXO---OXOX', 1)]
# [('--------O-------', (3, 3), '--------O------X', 0), ('--------O-----OX', (1, 3), '-------XO-----OX', 0), ('-------XO---O-OX', (1, 2), '------XXO---O-OX', 0), ('O-----XXO---O-OX', (3, 1), 'O-----XXO---OXOX', -1)]
# ----------------------------------------------------------------------------------------------------
# 9989:
# [('----------------', (3, 1), '-------------O--', 0), ('---X---------O--', (3, 2), '---X---------OO-', 0), ('---X-------X-OO-', (1, 2), '---X--O----X-OO-', 0), ('---X--O---XX-OO-', (1, 0), '---XO-O---XX-OO-', 0), ('--XXO-O---XX-OO-', (3, 3), '--XXO-O---XX-OOO', 0), ('--XXO-O---XXXOOO', (1, 3), '--XXO-OO--XXXOOO', 0), ('--XXO-OOX-XXXOOO', (2, 1), '--XXO-OOXOXXXOOO', 0), ('-XXXO-OOXOXXXOOO', (1, 1), '-XXXOOOOXOXXXOOO', 1)]
# [('-------------O--', (0, 3), '---X---------O--', 0), ('---X---------OO-', (2, 3), '---X-------X-OO-', 0), ('---X--O----X-OO-', (2, 2), '---X--O---XX-OO-', 0), ('---XO-O---XX-OO-', (0, 2), '--XXO-O---XX-OO-', 0), ('--XXO-O---XX-OOO', (3, 0), '--XXO-O---XXXOOO', 0), ('--XXO-OO--XXXOOO', (2, 0), '--XXO-OOX-XXXOOO', 0), ('--XXO-OOXOXXXOOO', (0, 1), '-XXXO-OOXOXXXOOO', -1)]
# ----------------------------------------------------------------------------------------------------
# 9990:
# [('----------------', (3, 2), '--------------O-', 0), ('------X-------O-', (2, 0), '------X-O-----O-', 0), ('------XXO-----O-', (3, 1), '------XXO----OO-', 0), ('------XXOX---OO-', (3, 3), '------XXOX---OOO', 0), ('---X--XXOX---OOO', (2, 2), '---X--XXOXO--OOO', 0), ('--XX--XXOXO--OOO', (2, 3), '--XX--XXOXOO-OOO', -1)]
# [('--------------O-', (1, 2), '------X-------O-', 0), ('------X-O-----O-', (1, 3), '------XXO-----O-', 0), ('------XXO----OO-', (2, 1), '------XXOX---OO-', 0), ('------XXOX---OOO', (0, 3), '---X--XXOX---OOO', 0), ('---X--XXOXO--OOO', (0, 2), '--XX--XXOXO--OOO', 0), ('--XX--XXOXOO-OOO', (3, 0), '--XX--XXOXOOXOOO', 1)]
# ----------------------------------------------------------------------------------------------------
# 9991:
# [('----------------', (0, 0), 'O---------------', 0), ('O-----------X---', (1, 1), 'O----O------X---', 0), ('O----O------X-X-', (2, 1), 'O----O---O--X-X-', 0), ('O--X-O---O--X-X-', (0, 1), 'OO-X-O---O--X-X-', 0), ('OO-XXO---O--X-X-', (2, 0), 'OO-XXO--OO--X-X-', 0), ('OO-XXO--OOX-X-X-', (0, 2), 'OOOXXO--OOX-X-X-', 0), ('OOOXXO--OOX-X-XX', (1, 2), 'OOOXXOO-OOX-X-XX', 0), ('OOOXXOOXOOX-X-XX', (3, 1), 'OOOXXOOXOOX-XOXX', 1)]
# [('O---------------', (3, 0), 'O-----------X---', 0), ('O----O------X---', (3, 2), 'O----O------X-X-', 0), ('O----O---O--X-X-', (0, 3), 'O--X-O---O--X-X-', 0), ('OO-X-O---O--X-X-', (1, 0), 'OO-XXO---O--X-X-', 0), ('OO-XXO--OO--X-X-', (2, 2), 'OO-XXO--OOX-X-X-', 0), ('OOOXXO--OOX-X-X-', (3, 3), 'OOOXXO--OOX-X-XX', 0), ('OOOXXOO-OOX-X-XX', (1, 3), 'OOOXXOOXOOX-X-XX', -1)]
# ----------------------------------------------------------------------------------------------------
# 9992:
# [('----------------', (2, 3), '-----------O----', 0), ('---------X-O----', (1, 1), '-----O---X-O----', 0), ('-----O-X-X-O----', (1, 0), '----OO-X-X-O----', 0), ('----OOXX-X-O----', (2, 0), '----OOXXOX-O----', 0), ('----OOXXOX-O---X', (0, 3), '---OOOXXOX-O---X', 0), ('---OOOXXOX-OX--X', (3, 1), '---OOOXXOX-OXO-X', 0), ('---OOOXXOXXOXO-X', (3, 2), '---OOOXXOXXOXOOX', 0), ('-X-OOOXXOXXOXOOX', (0, 0), 'OX-OOOXXOXXOXOOX', 0)]
# [('-----------O----', (2, 1), '---------X-O----', 0), ('-----O---X-O----', (1, 3), '-----O-X-X-O----', 0), ('----OO-X-X-O----', (1, 2), '----OOXX-X-O----', 0), ('----OOXXOX-O----', (3, 3), '----OOXXOX-O---X', 0), ('---OOOXXOX-O---X', (3, 0), '---OOOXXOX-OX--X', 0), ('---OOOXXOX-OXO-X', (2, 2), '---OOOXXOXXOXO-X', 0), ('---OOOXXOXXOXOOX', (0, 1), '-X-OOOXXOXXOXOOX', 0), ('OX-OOOXXOXXOXOOX', (0, 2), 'OXXOOOXXOXXOXOOX', 0)]
# ----------------------------------------------------------------------------------------------------
# 9993:
# [('----------------', (2, 0), '--------O-------', 0), ('--------O-----X-', (0, 1), '-O------O-----X-', 0), ('-O------O-X---X-', (1, 1), '-O---O--O-X---X-', 0), ('-O---OX-O-X---X-', (1, 0), '-O--OOX-O-X---X-', 0), ('-O-XOOX-O-X---X-', (0, 0), 'OO-XOOX-O-X---X-', -1)]
# [('--------O-------', (3, 2), '--------O-----X-', 0), ('-O------O-----X-', (2, 2), '-O------O-X---X-', 0), ('-O---O--O-X---X-', (1, 2), '-O---OX-O-X---X-', 0), ('-O--OOX-O-X---X-', (0, 3), '-O-XOOX-O-X---X-', 0), ('OO-XOOX-O-X---X-', (0, 2), 'OOXXOOX-O-X---X-', 1)]
# ----------------------------------------------------------------------------------------------------
# 9994:
# [('----------------', (2, 3), '-----------O----', 0), ('-------X---O----', (0, 2), '--O----X---O----', 0), ('--O----X-X-O----', (1, 1), '--O--O-X-X-O----', 0), ('X-O--O-X-X-O----', (1, 2), 'X-O--OOX-X-O----', 0), ('X-O--OOX-X-OX---', (0, 3), 'X-OO-OOX-X-OX---', 0), ('X-OO-OOX-X-OXX--', (2, 2), 'X-OO-OOX-XOOXX--', 0), ('X-OO-OOX-XOOXX-X', (2, 0), 'X-OO-OOXOXOOXX-X', -1)]
# [('-----------O----', (1, 3), '-------X---O----', 0), ('--O----X---O----', (2, 1), '--O----X-X-O----', 0), ('--O--O-X-X-O----', (0, 0), 'X-O--O-X-X-O----', 0), ('X-O--OOX-X-O----', (3, 0), 'X-O--OOX-X-OX---', 0), ('X-OO-OOX-X-OX---', (3, 1), 'X-OO-OOX-X-OXX--', 0), ('X-OO-OOX-XOOXX--', (3, 3), 'X-OO-OOX-XOOXX-X', 0), ('X-OO-OOXOXOOXX-X', (3, 2), 'X-OO-OOXOXOOXXXX', 1)]
# ----------------------------------------------------------------------------------------------------
# 9995:
# [('----------------', (1, 2), '------O---------', 0), ('------O-----X---', (0, 0), 'O-----O-----X---', 0), ('O-----O--X--X---', (2, 0), 'O-----O-OX--X---', 0), ('O-----O-OX--X-X-', (2, 2), 'O-----O-OXO-X-X-', 0), ('O---X-O-OXO-X-X-', (0, 1), 'OO--X-O-OXO-X-X-', 0), ('OOX-X-O-OXO-X-X-', (3, 1), 'OOX-X-O-OXO-XOX-', 0), ('OOXXX-O-OXO-XOX-', (1, 3), 'OOXXX-OOOXO-XOX-', 0), ('OOXXX-OOOXO-XOXX', (2, 3), 'OOXXX-OOOXOOXOXX', 0)]
# [('------O---------', (3, 0), '------O-----X---', 0), ('O-----O-----X---', (2, 1), 'O-----O--X--X---', 0), ('O-----O-OX--X---', (3, 2), 'O-----O-OX--X-X-', 0), ('O-----O-OXO-X-X-', (1, 0), 'O---X-O-OXO-X-X-', 0), ('OO--X-O-OXO-X-X-', (0, 2), 'OOX-X-O-OXO-X-X-', 0), ('OOX-X-O-OXO-XOX-', (0, 3), 'OOXXX-O-OXO-XOX-', 0), ('OOXXX-OOOXO-XOX-', (3, 3), 'OOXXX-OOOXO-XOXX', 0), ('OOXXX-OOOXOOXOXX', (1, 1), 'OOXXXXOOOXOOXOXX', 0)]
# ----------------------------------------------------------------------------------------------------
# 9996:
# [('----------------', (1, 1), '-----O----------', 0), ('-----O--X-------', (2, 3), '-----O--X--O----', 0), ('----XO--X--O----', (3, 3), '----XO--X--O---O', 0), ('-X--XO--X--O---O', (3, 2), '-X--XO--X--O--OO', 0), ('-XX-XO--X--O--OO', (2, 1), '-XX-XO--XO-O--OO', 0), ('-XX-XOX-XO-O--OO', (0, 3), '-XXOXOX-XO-O--OO', 0), ('XXXOXOX-XO-O--OO', (3, 0), 'XXXOXOX-XO-OO-OO', 0), ('XXXOXOX-XOXOO-OO', (1, 3), 'XXXOXOXOXOXOO-OO', 1)]
# [('-----O----------', (2, 0), '-----O--X-------', 0), ('-----O--X--O----', (1, 0), '----XO--X--O----', 0), ('----XO--X--O---O', (0, 1), '-X--XO--X--O---O', 0), ('-X--XO--X--O--OO', (0, 2), '-XX-XO--X--O--OO', 0), ('-XX-XO--XO-O--OO', (1, 2), '-XX-XOX-XO-O--OO', 0), ('-XXOXOX-XO-O--OO', (0, 0), 'XXXOXOX-XO-O--OO', 0), ('XXXOXOX-XO-OO-OO', (2, 2), 'XXXOXOX-XOXOO-OO', -1)]
# ----------------------------------------------------------------------------------------------------
# 9997:
# [('----------------', (3, 0), '------------O---', 0), ('---------X--O---', (2, 3), '---------X-OO---', 0), ('----X----X-OO---', (0, 3), '---OX----X-OO---', 0), ('---OX--X-X-OO---', (3, 3), '---OX--X-X-OO--O', 0), ('X--OX--X-X-OO--O', (3, 2), 'X--OX--X-X-OO-OO', 0), ('X--OX--X-X-OOXOO', (0, 2), 'X-OOX--X-X-OOXOO', 0), ('X-OOXX-X-X-OOXOO', (1, 2), 'X-OOXXOX-X-OOXOO', -1)]
# [('------------O---', (2, 1), '---------X--O---', 0), ('---------X-OO---', (1, 0), '----X----X-OO---', 0), ('---OX----X-OO---', (1, 3), '---OX--X-X-OO---', 0), ('---OX--X-X-OO--O', (0, 0), 'X--OX--X-X-OO--O', 0), ('X--OX--X-X-OO-OO', (3, 1), 'X--OX--X-X-OOXOO', 0), ('X-OOX--X-X-OOXOO', (1, 1), 'X-OOXX-X-X-OOXOO', 0), ('X-OOXXOX-X-OOXOO', (0, 1), 'XXOOXXOX-X-OOXOO', 1)]
# ----------------------------------------------------------------------------------------------------
# 9998:
# [('----------------', (3, 0), '------------O---', 0), ('------------OX--', (1, 3), '-------O----OX--', 0), ('-------OX---OX--', (2, 2), '-------OX-O-OX--', 0), ('----X--OX-O-OX--', (2, 3), '----X--OX-OOOX--', 0), ('----X--OXXOOOX--', (1, 1), '----XO-OXXOOOX--', 0), ('--X-XO-OXXOOOX--', (3, 2), '--X-XO-OXXOOOXO-', 0), ('X-X-XO-OXXOOOXO-', (0, 3), 'X-XOXO-OXXOOOXO-', 0), ('XXXOXO-OXXOOOXO-', (3, 3), 'XXXOXO-OXXOOOXOO', 1)]
# [('------------O---', (3, 1), '------------OX--', 0), ('-------O----OX--', (2, 0), '-------OX---OX--', 0), ('-------OX-O-OX--', (1, 0), '----X--OX-O-OX--', 0), ('----X--OX-OOOX--', (2, 1), '----X--OXXOOOX--', 0), ('----XO-OXXOOOX--', (0, 2), '--X-XO-OXXOOOX--', 0), ('--X-XO-OXXOOOXO-', (0, 0), 'X-X-XO-OXXOOOXO-', 0), ('X-XOXO-OXXOOOXO-', (0, 1), 'XXXOXO-OXXOOOXO-', -1)]
# ----------------------------------------------------------------------------------------------------
# 9999:
# [('----------------', (1, 3), '-------O--------', 0), ('-------O---X----', (3, 1), '-------O---X-O--', 0), ('-------O-X-X-O--', (3, 3), '-------O-X-X-O-O', 0), ('-------OXX-X-O-O', (0, 0), 'O------OXX-X-O-O', 0), ('O------OXX-X-OXO', (3, 0), 'O------OXX-XOOXO', 0), ('O----X-OXX-XOOXO', (1, 0), 'O---OX-OXX-XOOXO', 0), ('O-X-OX-OXX-XOOXO', (0, 1), 'OOX-OX-OXX-XOOXO', -1)]
# [('-------O--------', (2, 3), '-------O---X----', 0), ('-------O---X-O--', (2, 1), '-------O-X-X-O--', 0), ('-------O-X-X-O-O', (2, 0), '-------OXX-X-O-O', 0), ('O------OXX-X-O-O', (3, 2), 'O------OXX-X-OXO', 0), ('O------OXX-XOOXO', (1, 1), 'O----X-OXX-XOOXO', 0), ('O---OX-OXX-XOOXO', (0, 2), 'O-X-OX-OXX-XOOXO', 0), ('OOX-OX-OXX-XOOXO', (2, 2), 'OOX-OX-OXXXXOOXO', 1)]
# ----------------------------------------------------------------------------------------------------
# None

# %%
import os
import pickle
import sys
import numpy as np
import matplotlib.pylab as plt

with open("agent_1.pkl", 'rb') as f:
    agent = pickle.load(f)

def plot_agent_reward(rewards):
    """ Function to plot agent's accumulated reward vs. iteration """

    # Plot cumulative rewards
    plt.plot(np.cumsum(rewards))

    # Set the title and labels
    plt.title('Agent Cumulative Reward vs. Iteration Monte Carlo 4x4')
    plt.ylabel('Reward')
    plt.xlabel('Episode')

    # Improve x-axis by adding more ticks
    num_episodes = len(rewards)
    plt.xticks(np.arange(0, num_episodes, step=max(1, num_episodes // 10)))  # Adjust the step to control tick frequency

    # Optionally, rotate x-tick labels if they overlap
    plt.xticks(rotation=45)

    # Show the plot
    plt.show()
plot_agent_reward(agent.rewards)
